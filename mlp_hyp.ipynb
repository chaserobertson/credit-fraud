# %% [markdown]
# <a href="https://colab.research.google.com/github/chaserobertson/credit-fraud/blob/main/mlp_hyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet mealpy
# !pip install --quiet permetrics

# %%
# !/usr/bin/env python
# Created by "Thieu" at 23:59, 14/12/2021 ----------%
#       Email: nguyenthieu2102@gmail.com            %
#       Github: https://github.com/thieu1995        %
# --------------------------------------------------%

# https://machinelearningmastery.com/how-to-develop-multilayer-perceptron-models-for-time-series-forecasting/

# 1. Fitness function
# 2. Lower bound and upper bound of variables
# 3. Min or max
# 4. Number of dimensions (number of variables)


# Assumption that we are trying to optimize the multi-layer perceptron with 3 layer 1 input, 1 hidden, 1 output.
# 1. Batch-size training
# 2. Epoch training
# 3. Optimizer
# 4. Learning rate
# 5. network weight initialization
# 6. activation functions
# 7. number of hidden units

# Rules:
# 1. Batch-size: [ 2, 4, 8 ]
# 2. Epoch : [700, 800, .... 2000]
# 3. Optimizer: ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
# 4. Learning rate: [0.01 -> 0.5]       real number
# 5. network weight initialization: ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']
# 6. activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']
# 7. hidden units: [5, 100] --> integer number


# solution = [ x1, x2, x3, x4, x5, x6, x7, x8,  ]

# 1st solution: hidden layer = 2  ==> [ x1, x2, x3, x4, x5, x6, x7, x8, x9, x10 ]
# x9: the number of hidden units of layer 1
# x10: the number of hidden units of layer 2
# 2nd solution: hidden layer = 4 ==> [ x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12 ]
# But in Metaheuristic Process --> You can not expand the solution.
# The number of dimensions is fixed before and after the MH process.


# 1 way: solution = [ x1, x2, x3, x4, x5, x6, x7, x8,  ]
# x8: should be the number of hidden layer
# x7: should be the number of hidden node in each layer --> all hidden layer has the same number of hidden node.


# 2 way: I limit the number of hidden layers to 5. Number of hidden layers belongs [1, 5]

# solution = [ x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13 ]
# x8: number of hidden layers
# x9: number of hidden units in 1st the hidden layer
# x10: ..... 2nd hidden layer
# x11: .... 3rd hidden layer
# x12: .... 4th hidden layer
# x13: .... 5th hidden layer

# if a solution with x8 = 2 hidden layers ==>
# x9, x10 --> then ignore other values: x11, x12, x13

# solution 1 = [x1, x2, x3, x4, x5, x6, x7, x8, 100, 50, 10, 10, 10]
# solution 2 = [x1, x2, x3, x4, x5, x6, x7, x8, 100, 50, 10, 10, 20]
# solution 3 = [x1, x2, x3, x4, x5, x6, x7, x8, 100, 50, 10, 10, 30]

# 8. Number of hidden layers with number of hidden nodes in each layers.


# univariate mlp example
import numpy as np
import tensorflow as tf
import keras
from keras import backend as k

import statsmodels.datasets.co2 as co2
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from permetrics.regression import RegressionMetric
#from mealpy.examples.applications.keras.timeseries_util import decode_solution, generate_loss_value
from mealpy.evolutionary_based import FPA
from mealpy.swarm_based import PSO


# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    ## https://machinelearningmastery.com/machine-learning-data-transforms-for-time-series-forecasting/
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence) - 1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


def generate_data():
    ## Make dataset
    dataset = co2.load(as_pandas=True).data
    dataset = dataset.fillna(dataset.interpolate())
    scaler = MinMaxScaler()
    scaled_seq = scaler.fit_transform(dataset.values).flatten()

    # choose a number of time steps
    n_steps = 3
    # split into samples            60% - training
    x_train_point = int(len(scaled_seq) * 0.75)
    X_train, y_train = split_sequence(scaled_seq[:x_train_point], n_steps)
    X_test, y_test = split_sequence(scaled_seq[x_train_point:], n_steps)

    return {"X_train": X_train, "y_train": y_train, "X_test": X_test, "y_test": y_test, "n_steps": n_steps}


def decode_solution(solution, data):
    batch_size = 2 ** int(solution[0])
    epoch = 10 * int(solution[1])
    opt_integer = int(solution[2])
    opt = data["OPT_ENCODER"].inverse_transform([opt_integer])[0]
    learning_rate = solution[3]
    network_weight_initial_integer = int(solution[4])
    network_weight_initial = data["WOI_ENCODER"].inverse_transform([network_weight_initial_integer])[0]
    act_integer = int(solution[5])
    activation = data["ACT_ENCODER"].inverse_transform([act_integer])[0]
    n_hidden_units = int(solution[6])
    return {
        "batch_size": batch_size,
        "epoch": epoch,
        "opt": opt,
        "learning_rate": learning_rate,
        "network_weight_initial": network_weight_initial,
        "activation": activation,
        "n_hidden_units": n_hidden_units,
    }


def generate_loss_value(structure, data):
    # define model
    model = Sequential()
    model.add(Dense(structure["n_hidden_units"], activation=structure["activation"],
                    input_dim=data["n_steps"], kernel_initializer=structure["network_weight_initial"]))
    model.add(Dense(1))

    # Compile model
    optimizer = getattr(tf.keras.optimizers, structure["opt"])(learning_rate=structure["learning_rate"])
    model.compile(optimizer=optimizer, loss='mse')

    # fit model
    model.fit(data["X_train"], data["y_train"], epochs=structure["epoch"], batch_size=structure["batch_size"], verbose=2)

    # We take the loss value of validation set as a fitness value for selecting
    # the best model demonstrate prediction
    y_pred = model.predict(data["X_test"])

    evaluator = RegressionMetric(data["y_test"], y_pred, decimal=6)
    return evaluator.mean_squared_error()


def fitness_function(solution, data):
    structure = decode_solution(solution, data)
    fitness = generate_loss_value(structure, data)
    return fitness


if __name__ == "__main__":
    # LABEL ENCODER
    OPT_ENCODER = LabelEncoder()
    OPT_ENCODER.fit(['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam'])  # domain range ==> 7 values

    WOI_ENCODER = LabelEncoder()
    WOI_ENCODER.fit(['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform'])

    ACT_ENCODER = LabelEncoder()
    ACT_ENCODER.fit(['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear'])

    DATA = generate_data()
    DATA["OPT_ENCODER"] = OPT_ENCODER
    DATA["WOI_ENCODER"] = WOI_ENCODER
    DATA["ACT_ENCODER"] = ACT_ENCODER

    LB = [1, 5, 0, 0.01, 0, 0, 5]
    UB = [3.99, 20.99, 6.99, 0.5, 7.99, 7.99, 50]

    problem = {
        "fit_func": fitness_function,
        "lb": LB,
        "ub": UB,
        "minmax": "min",
        "log_to": None,
        "save_population": False,
        "data": DATA,
    }
    # model = FPA.BaseFPA(problem, epoch=5, pop_size=20)
    model = PSO.BasePSO(problem, epoch=5, pop_size=20)
    model.solve()

    print(f"Best solution: {model.solution[0]}")
    sol = decode_solution(model.solution[0], DATA)

    print(f"Batch-size: {sol['batch_size']}, Epoch: {sol['epoch']}, Opt: {sol['opt']}, "
          f"Learning-rate: {sol['learning_rate']}, NWI: {sol['network_weight_initial']}, "
          f"Activation: {sol['activation']}, n-hidden: {sol['n_hidden_units']}")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Streaming output truncated to the last 5000 lines.
# Epoch 19/200
# 214/214 - 0s - loss: 1.1653e-04 - 266ms/epoch - 1ms/step
# Epoch 20/200
# 214/214 - 0s - loss: 1.1754e-04 - 255ms/epoch - 1ms/step
# Epoch 21/200
# 214/214 - 0s - loss: 1.2825e-04 - 283ms/epoch - 1ms/step
# Epoch 22/200
# 214/214 - 0s - loss: 1.1467e-04 - 284ms/epoch - 1ms/step
# Epoch 23/200
# 214/214 - 0s - loss: 1.1658e-04 - 262ms/epoch - 1ms/step
# Epoch 24/200
# 214/214 - 0s - loss: 1.2054e-04 - 277ms/epoch - 1ms/step
# Epoch 25/200
# 214/214 - 0s - loss: 1.1976e-04 - 272ms/epoch - 1ms/step
# Epoch 26/200
# 214/214 - 0s - loss: 1.1306e-04 - 287ms/epoch - 1ms/step
# Epoch 27/200
# 214/214 - 0s - loss: 1.2813e-04 - 280ms/epoch - 1ms/step
# Epoch 28/200
# 214/214 - 0s - loss: 1.1477e-04 - 270ms/epoch - 1ms/step
# Epoch 29/200
# 214/214 - 0s - loss: 1.0961e-04 - 259ms/epoch - 1ms/step
# Epoch 30/200
# 214/214 - 0s - loss: 1.1315e-04 - 266ms/epoch - 1ms/step
# Epoch 31/200
# 214/214 - 0s - loss: 1.2350e-04 - 259ms/epoch - 1ms/step
# Epoch 32/200
# 214/214 - 0s - loss: 1.0635e-04 - 257ms/epoch - 1ms/step
# Epoch 33/200
# 214/214 - 0s - loss: 1.1206e-04 - 261ms/epoch - 1ms/step
# Epoch 34/200
# 214/214 - 0s - loss: 1.0600e-04 - 274ms/epoch - 1ms/step
# Epoch 35/200
# 214/214 - 0s - loss: 1.0685e-04 - 268ms/epoch - 1ms/step
# Epoch 36/200
# 214/214 - 0s - loss: 1.0735e-04 - 288ms/epoch - 1ms/step
# Epoch 37/200
# 214/214 - 0s - loss: 1.0502e-04 - 285ms/epoch - 1ms/step
# Epoch 38/200
# 214/214 - 0s - loss: 1.0617e-04 - 260ms/epoch - 1ms/step
# Epoch 39/200
# 214/214 - 0s - loss: 1.0987e-04 - 280ms/epoch - 1ms/step
# Epoch 40/200
# 214/214 - 0s - loss: 1.0189e-04 - 268ms/epoch - 1ms/step
# Epoch 41/200
# 214/214 - 0s - loss: 1.0049e-04 - 255ms/epoch - 1ms/step
# Epoch 42/200
# 214/214 - 0s - loss: 9.9348e-05 - 262ms/epoch - 1ms/step
# Epoch 43/200
# 214/214 - 0s - loss: 1.1086e-04 - 253ms/epoch - 1ms/step
# Epoch 44/200
# 214/214 - 0s - loss: 1.1456e-04 - 274ms/epoch - 1ms/step
# Epoch 45/200
# 214/214 - 0s - loss: 9.2184e-05 - 267ms/epoch - 1ms/step
# Epoch 46/200
# 214/214 - 0s - loss: 9.7718e-05 - 263ms/epoch - 1ms/step
# Epoch 47/200
# 214/214 - 0s - loss: 9.9415e-05 - 249ms/epoch - 1ms/step
# Epoch 48/200
# 214/214 - 0s - loss: 1.0617e-04 - 262ms/epoch - 1ms/step
# Epoch 49/200
# 214/214 - 0s - loss: 9.5192e-05 - 260ms/epoch - 1ms/step
# Epoch 50/200
# 214/214 - 0s - loss: 1.0379e-04 - 252ms/epoch - 1ms/step
# Epoch 51/200
# 214/214 - 0s - loss: 9.4685e-05 - 260ms/epoch - 1ms/step
# Epoch 52/200
# 214/214 - 0s - loss: 9.1266e-05 - 253ms/epoch - 1ms/step
# Epoch 53/200
# 214/214 - 0s - loss: 9.3343e-05 - 256ms/epoch - 1ms/step
# Epoch 54/200
# 214/214 - 0s - loss: 1.0281e-04 - 258ms/epoch - 1ms/step
# Epoch 55/200
# 214/214 - 0s - loss: 9.5088e-05 - 281ms/epoch - 1ms/step
# Epoch 56/200
# 214/214 - 0s - loss: 8.6937e-05 - 257ms/epoch - 1ms/step
# Epoch 57/200
# 214/214 - 0s - loss: 9.8452e-05 - 264ms/epoch - 1ms/step
# Epoch 58/200
# 214/214 - 0s - loss: 8.6975e-05 - 286ms/epoch - 1ms/step
# Epoch 59/200
# 214/214 - 0s - loss: 9.1337e-05 - 256ms/epoch - 1ms/step
# Epoch 60/200
# 214/214 - 0s - loss: 9.4033e-05 - 265ms/epoch - 1ms/step
# Epoch 61/200
# 214/214 - 0s - loss: 8.8555e-05 - 262ms/epoch - 1ms/step
# Epoch 62/200
# 214/214 - 0s - loss: 9.0639e-05 - 268ms/epoch - 1ms/step
# Epoch 63/200
# 214/214 - 0s - loss: 8.9131e-05 - 255ms/epoch - 1ms/step
# Epoch 64/200
# 214/214 - 0s - loss: 8.5890e-05 - 271ms/epoch - 1ms/step
# Epoch 65/200
# 214/214 - 0s - loss: 8.9368e-05 - 264ms/epoch - 1ms/step
# Epoch 66/200
# 214/214 - 0s - loss: 8.7509e-05 - 260ms/epoch - 1ms/step
# Epoch 67/200
# 214/214 - 0s - loss: 9.1477e-05 - 247ms/epoch - 1ms/step
# Epoch 68/200
# 214/214 - 0s - loss: 8.6564e-05 - 269ms/epoch - 1ms/step
# Epoch 69/200
# 214/214 - 0s - loss: 8.9597e-05 - 265ms/epoch - 1ms/step
# Epoch 70/200
# 214/214 - 0s - loss: 8.5526e-05 - 251ms/epoch - 1ms/step
# Epoch 71/200
# 214/214 - 0s - loss: 8.2604e-05 - 255ms/epoch - 1ms/step
# Epoch 72/200
# 214/214 - 0s - loss: 8.2383e-05 - 254ms/epoch - 1ms/step
# Epoch 73/200
# 214/214 - 0s - loss: 8.9722e-05 - 274ms/epoch - 1ms/step
# Epoch 74/200
# 214/214 - 0s - loss: 9.1396e-05 - 262ms/epoch - 1ms/step
# Epoch 75/200
# 214/214 - 0s - loss: 8.8403e-05 - 272ms/epoch - 1ms/step
# Epoch 76/200
# 214/214 - 0s - loss: 9.2557e-05 - 264ms/epoch - 1ms/step
# Epoch 77/200
# 214/214 - 0s - loss: 8.2175e-05 - 291ms/epoch - 1ms/step
# Epoch 78/200
# 214/214 - 0s - loss: 8.7000e-05 - 261ms/epoch - 1ms/step
# Epoch 79/200
# 214/214 - 0s - loss: 8.7538e-05 - 280ms/epoch - 1ms/step
# Epoch 80/200
# 214/214 - 0s - loss: 9.0249e-05 - 271ms/epoch - 1ms/step
# Epoch 81/200
# 214/214 - 0s - loss: 7.8126e-05 - 267ms/epoch - 1ms/step
# Epoch 82/200
# 214/214 - 0s - loss: 8.4687e-05 - 267ms/epoch - 1ms/step
# Epoch 83/200
# 214/214 - 0s - loss: 8.5405e-05 - 261ms/epoch - 1ms/step
# Epoch 84/200
# 214/214 - 0s - loss: 7.5105e-05 - 265ms/epoch - 1ms/step
# Epoch 85/200
# 214/214 - 0s - loss: 7.9343e-05 - 251ms/epoch - 1ms/step
# Epoch 86/200
# 214/214 - 0s - loss: 8.3652e-05 - 252ms/epoch - 1ms/step
# Epoch 87/200
# 214/214 - 0s - loss: 7.8930e-05 - 274ms/epoch - 1ms/step
# Epoch 88/200
# 214/214 - 0s - loss: 8.2038e-05 - 246ms/epoch - 1ms/step
# Epoch 89/200
# 214/214 - 0s - loss: 8.2057e-05 - 254ms/epoch - 1ms/step
# Epoch 90/200
# 214/214 - 0s - loss: 8.0794e-05 - 264ms/epoch - 1ms/step
# Epoch 91/200
# 214/214 - 0s - loss: 8.1582e-05 - 263ms/epoch - 1ms/step
# Epoch 92/200
# 214/214 - 0s - loss: 8.3199e-05 - 255ms/epoch - 1ms/step
# Epoch 93/200
# 214/214 - 0s - loss: 8.2441e-05 - 252ms/epoch - 1ms/step
# Epoch 94/200
# 214/214 - 0s - loss: 8.0860e-05 - 286ms/epoch - 1ms/step
# Epoch 95/200
# 214/214 - 0s - loss: 8.2008e-05 - 281ms/epoch - 1ms/step
# Epoch 96/200
# 214/214 - 0s - loss: 8.3179e-05 - 259ms/epoch - 1ms/step
# Epoch 97/200
# 214/214 - 0s - loss: 8.0353e-05 - 248ms/epoch - 1ms/step
# Epoch 98/200
# 214/214 - 0s - loss: 7.6509e-05 - 262ms/epoch - 1ms/step
# Epoch 99/200
# 214/214 - 0s - loss: 7.4991e-05 - 268ms/epoch - 1ms/step
# Epoch 100/200
# 214/214 - 0s - loss: 7.6939e-05 - 261ms/epoch - 1ms/step
# Epoch 101/200
# 214/214 - 0s - loss: 8.1486e-05 - 249ms/epoch - 1ms/step
# Epoch 102/200
# 214/214 - 0s - loss: 7.2803e-05 - 283ms/epoch - 1ms/step
# Epoch 103/200
# 214/214 - 0s - loss: 7.2857e-05 - 261ms/epoch - 1ms/step
# Epoch 104/200
# 214/214 - 0s - loss: 7.6737e-05 - 267ms/epoch - 1ms/step
# Epoch 105/200
# 214/214 - 0s - loss: 7.8966e-05 - 251ms/epoch - 1ms/step
# Epoch 106/200
# 214/214 - 0s - loss: 7.5926e-05 - 275ms/epoch - 1ms/step
# Epoch 107/200
# 214/214 - 0s - loss: 7.2332e-05 - 247ms/epoch - 1ms/step
# Epoch 108/200
# 214/214 - 0s - loss: 8.3145e-05 - 265ms/epoch - 1ms/step
# Epoch 109/200
# 214/214 - 0s - loss: 7.2238e-05 - 274ms/epoch - 1ms/step
# Epoch 110/200
# 214/214 - 0s - loss: 7.9070e-05 - 260ms/epoch - 1ms/step
# Epoch 111/200
# 214/214 - 0s - loss: 7.4955e-05 - 255ms/epoch - 1ms/step
# Epoch 112/200
# 214/214 - 0s - loss: 8.1007e-05 - 251ms/epoch - 1ms/step
# Epoch 113/200
# 214/214 - 0s - loss: 6.9774e-05 - 279ms/epoch - 1ms/step
# Epoch 114/200
# 214/214 - 0s - loss: 7.6359e-05 - 246ms/epoch - 1ms/step
# Epoch 115/200
# 214/214 - 0s - loss: 8.2080e-05 - 260ms/epoch - 1ms/step
# Epoch 116/200
# 214/214 - 0s - loss: 7.8880e-05 - 250ms/epoch - 1ms/step
# Epoch 117/200
# 214/214 - 0s - loss: 7.2792e-05 - 257ms/epoch - 1ms/step
# Epoch 118/200
# 214/214 - 0s - loss: 7.4974e-05 - 255ms/epoch - 1ms/step
# Epoch 119/200
# 214/214 - 0s - loss: 7.6310e-05 - 261ms/epoch - 1ms/step
# Epoch 120/200
# 214/214 - 0s - loss: 7.0603e-05 - 255ms/epoch - 1ms/step
# Epoch 121/200
# 214/214 - 0s - loss: 7.5933e-05 - 274ms/epoch - 1ms/step
# Epoch 122/200
# 214/214 - 0s - loss: 7.5356e-05 - 261ms/epoch - 1ms/step
# Epoch 123/200
# 214/214 - 0s - loss: 7.3888e-05 - 269ms/epoch - 1ms/step
# Epoch 124/200
# 214/214 - 0s - loss: 7.4909e-05 - 255ms/epoch - 1ms/step
# Epoch 125/200
# 214/214 - 0s - loss: 7.4487e-05 - 277ms/epoch - 1ms/step
# Epoch 126/200
# 214/214 - 0s - loss: 7.2054e-05 - 268ms/epoch - 1ms/step
# Epoch 127/200
# 214/214 - 0s - loss: 7.7991e-05 - 259ms/epoch - 1ms/step
# Epoch 128/200
# 214/214 - 0s - loss: 7.7398e-05 - 264ms/epoch - 1ms/step
# Epoch 129/200
# 214/214 - 0s - loss: 8.1582e-05 - 265ms/epoch - 1ms/step
# Epoch 130/200
# 214/214 - 0s - loss: 7.2845e-05 - 264ms/epoch - 1ms/step
# Epoch 131/200
# 214/214 - 0s - loss: 7.5655e-05 - 272ms/epoch - 1ms/step
# Epoch 132/200
# 214/214 - 0s - loss: 7.5151e-05 - 288ms/epoch - 1ms/step
# Epoch 133/200
# 214/214 - 0s - loss: 7.9237e-05 - 254ms/epoch - 1ms/step
# Epoch 134/200
# 214/214 - 0s - loss: 7.1828e-05 - 264ms/epoch - 1ms/step
# Epoch 135/200
# 214/214 - 0s - loss: 7.7802e-05 - 252ms/epoch - 1ms/step
# Epoch 136/200
# 214/214 - 0s - loss: 7.3561e-05 - 263ms/epoch - 1ms/step
# Epoch 137/200
# 214/214 - 0s - loss: 7.7755e-05 - 256ms/epoch - 1ms/step
# Epoch 138/200
# 214/214 - 0s - loss: 7.2302e-05 - 262ms/epoch - 1ms/step
# Epoch 139/200
# 214/214 - 0s - loss: 7.1050e-05 - 262ms/epoch - 1ms/step
# Epoch 140/200
# 214/214 - 0s - loss: 7.2149e-05 - 291ms/epoch - 1ms/step
# Epoch 141/200
# 214/214 - 0s - loss: 7.3383e-05 - 264ms/epoch - 1ms/step
# Epoch 142/200
# 214/214 - 0s - loss: 7.4499e-05 - 246ms/epoch - 1ms/step
# Epoch 143/200
# 214/214 - 0s - loss: 7.2746e-05 - 247ms/epoch - 1ms/step
# Epoch 144/200
# 214/214 - 0s - loss: 7.8042e-05 - 278ms/epoch - 1ms/step
# Epoch 145/200
# 214/214 - 0s - loss: 7.3696e-05 - 264ms/epoch - 1ms/step
# Epoch 146/200
# 214/214 - 0s - loss: 7.4596e-05 - 244ms/epoch - 1ms/step
# Epoch 147/200
# 214/214 - 0s - loss: 7.0054e-05 - 266ms/epoch - 1ms/step
# Epoch 148/200
# 214/214 - 0s - loss: 7.8301e-05 - 260ms/epoch - 1ms/step
# Epoch 149/200
# 214/214 - 0s - loss: 7.4531e-05 - 266ms/epoch - 1ms/step
# Epoch 150/200
# 214/214 - 0s - loss: 7.7619e-05 - 256ms/epoch - 1ms/step
# Epoch 151/200
# 214/214 - 0s - loss: 7.5507e-05 - 255ms/epoch - 1ms/step
# Epoch 152/200
# 214/214 - 0s - loss: 7.2714e-05 - 253ms/epoch - 1ms/step
# Epoch 153/200
# 214/214 - 0s - loss: 7.5351e-05 - 254ms/epoch - 1ms/step
# Epoch 154/200
# 214/214 - 0s - loss: 7.1236e-05 - 250ms/epoch - 1ms/step
# Epoch 155/200
# 214/214 - 0s - loss: 7.7685e-05 - 299ms/epoch - 1ms/step
# Epoch 156/200
# 214/214 - 0s - loss: 7.3381e-05 - 251ms/epoch - 1ms/step
# Epoch 157/200
# 214/214 - 0s - loss: 7.2994e-05 - 244ms/epoch - 1ms/step
# Epoch 158/200
# 214/214 - 0s - loss: 7.8496e-05 - 259ms/epoch - 1ms/step
# Epoch 159/200
# 214/214 - 0s - loss: 7.2132e-05 - 264ms/epoch - 1ms/step
# Epoch 160/200
# 214/214 - 0s - loss: 7.0686e-05 - 278ms/epoch - 1ms/step
# Epoch 161/200
# 214/214 - 0s - loss: 8.0250e-05 - 279ms/epoch - 1ms/step
# Epoch 162/200
# 214/214 - 0s - loss: 7.7732e-05 - 278ms/epoch - 1ms/step
# Epoch 163/200
# 214/214 - 0s - loss: 7.7310e-05 - 273ms/epoch - 1ms/step
# Epoch 164/200
# 214/214 - 0s - loss: 7.7626e-05 - 259ms/epoch - 1ms/step
# Epoch 165/200
# 214/214 - 0s - loss: 7.4208e-05 - 252ms/epoch - 1ms/step
# Epoch 166/200
# 214/214 - 0s - loss: 7.2718e-05 - 259ms/epoch - 1ms/step
# Epoch 167/200
# 214/214 - 0s - loss: 7.4329e-05 - 271ms/epoch - 1ms/step
# Epoch 168/200
# 214/214 - 0s - loss: 6.7872e-05 - 279ms/epoch - 1ms/step
# Epoch 169/200
# 214/214 - 0s - loss: 7.5054e-05 - 256ms/epoch - 1ms/step
# Epoch 170/200
# 214/214 - 0s - loss: 7.3073e-05 - 249ms/epoch - 1ms/step
# Epoch 171/200
# 214/214 - 0s - loss: 8.1011e-05 - 251ms/epoch - 1ms/step
# Epoch 172/200
# 214/214 - 0s - loss: 7.1931e-05 - 254ms/epoch - 1ms/step
# Epoch 173/200
# 214/214 - 0s - loss: 7.2037e-05 - 289ms/epoch - 1ms/step
# Epoch 174/200
# 214/214 - 0s - loss: 7.2976e-05 - 283ms/epoch - 1ms/step
# Epoch 175/200
# 214/214 - 0s - loss: 7.3117e-05 - 284ms/epoch - 1ms/step
# Epoch 176/200
# 214/214 - 0s - loss: 7.4227e-05 - 285ms/epoch - 1ms/step
# Epoch 177/200
# 214/214 - 0s - loss: 6.7582e-05 - 272ms/epoch - 1ms/step
# Epoch 178/200
# 214/214 - 0s - loss: 8.1619e-05 - 296ms/epoch - 1ms/step
# Epoch 179/200
# 214/214 - 0s - loss: 7.7328e-05 - 262ms/epoch - 1ms/step
# Epoch 180/200
# 214/214 - 0s - loss: 7.5119e-05 - 267ms/epoch - 1ms/step
# Epoch 181/200
# 214/214 - 0s - loss: 7.5058e-05 - 267ms/epoch - 1ms/step
# Epoch 182/200
# 214/214 - 0s - loss: 8.0156e-05 - 264ms/epoch - 1ms/step
# Epoch 183/200
# 214/214 - 0s - loss: 6.8825e-05 - 268ms/epoch - 1ms/step
# Epoch 184/200
# 214/214 - 0s - loss: 7.9924e-05 - 266ms/epoch - 1ms/step
# Epoch 185/200
# 214/214 - 0s - loss: 7.4133e-05 - 272ms/epoch - 1ms/step
# Epoch 186/200
# 214/214 - 0s - loss: 7.1871e-05 - 262ms/epoch - 1ms/step
# Epoch 187/200
# 214/214 - 0s - loss: 7.0445e-05 - 257ms/epoch - 1ms/step
# Epoch 188/200
# 214/214 - 0s - loss: 7.2441e-05 - 262ms/epoch - 1ms/step
# Epoch 189/200
# 214/214 - 0s - loss: 7.3173e-05 - 260ms/epoch - 1ms/step
# Epoch 190/200
# 214/214 - 0s - loss: 7.2264e-05 - 260ms/epoch - 1ms/step
# Epoch 191/200
# 214/214 - 0s - loss: 7.1240e-05 - 261ms/epoch - 1ms/step
# Epoch 192/200
# 214/214 - 0s - loss: 7.3134e-05 - 252ms/epoch - 1ms/step
# Epoch 193/200
# 214/214 - 0s - loss: 6.9594e-05 - 264ms/epoch - 1ms/step
# Epoch 194/200
# 214/214 - 0s - loss: 7.1671e-05 - 263ms/epoch - 1ms/step
# Epoch 195/200
# 214/214 - 0s - loss: 7.1278e-05 - 267ms/epoch - 1ms/step
# Epoch 196/200
# 214/214 - 0s - loss: 7.4323e-05 - 263ms/epoch - 1ms/step
# Epoch 197/200
# 214/214 - 0s - loss: 7.8615e-05 - 274ms/epoch - 1ms/step
# Epoch 198/200
# 214/214 - 0s - loss: 7.1483e-05 - 265ms/epoch - 1ms/step
# Epoch 199/200
# 214/214 - 0s - loss: 8.0451e-05 - 247ms/epoch - 1ms/step
# Epoch 200/200
# 214/214 - 0s - loss: 7.1549e-05 - 283ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step
# Epoch 1/190
# 214/214 - 1s - loss: 0.1247 - 567ms/epoch - 3ms/step
# Epoch 2/190
# 214/214 - 0s - loss: 0.1050 - 253ms/epoch - 1ms/step
# Epoch 3/190
# 214/214 - 0s - loss: 0.0880 - 253ms/epoch - 1ms/step
# Epoch 4/190
# 214/214 - 0s - loss: 0.0741 - 255ms/epoch - 1ms/step
# Epoch 5/190
# 214/214 - 0s - loss: 0.0632 - 271ms/epoch - 1ms/step
# Epoch 6/190
# 214/214 - 0s - loss: 0.0551 - 256ms/epoch - 1ms/step
# Epoch 7/190
# 214/214 - 0s - loss: 0.0492 - 255ms/epoch - 1ms/step
# Epoch 8/190
# 214/214 - 0s - loss: 0.0452 - 269ms/epoch - 1ms/step
# Epoch 9/190
# 214/214 - 0s - loss: 0.0426 - 280ms/epoch - 1ms/step
# Epoch 10/190
# 214/214 - 0s - loss: 0.0408 - 279ms/epoch - 1ms/step
# Epoch 11/190
# 214/214 - 0s - loss: 0.0397 - 273ms/epoch - 1ms/step
# Epoch 12/190
# 214/214 - 0s - loss: 0.0391 - 269ms/epoch - 1ms/step
# Epoch 13/190
# 214/214 - 0s - loss: 0.0387 - 266ms/epoch - 1ms/step
# Epoch 14/190
# 214/214 - 0s - loss: 0.0385 - 257ms/epoch - 1ms/step
# Epoch 15/190
# 214/214 - 0s - loss: 0.0384 - 249ms/epoch - 1ms/step
# Epoch 16/190
# 214/214 - 0s - loss: 0.0383 - 272ms/epoch - 1ms/step
# Epoch 17/190
# 214/214 - 0s - loss: 0.0383 - 258ms/epoch - 1ms/step
# Epoch 18/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 19/190
# 214/214 - 0s - loss: 0.0383 - 292ms/epoch - 1ms/step
# Epoch 20/190
# 214/214 - 0s - loss: 0.0383 - 280ms/epoch - 1ms/step
# Epoch 21/190
# 214/214 - 0s - loss: 0.0383 - 258ms/epoch - 1ms/step
# Epoch 22/190
# 214/214 - 0s - loss: 0.0383 - 264ms/epoch - 1ms/step
# Epoch 23/190
# 214/214 - 0s - loss: 0.0383 - 300ms/epoch - 1ms/step
# Epoch 24/190
# 214/214 - 0s - loss: 0.0383 - 257ms/epoch - 1ms/step
# Epoch 25/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 26/190
# 214/214 - 0s - loss: 0.0383 - 251ms/epoch - 1ms/step
# Epoch 27/190
# 214/214 - 0s - loss: 0.0383 - 264ms/epoch - 1ms/step
# Epoch 28/190
# 214/214 - 0s - loss: 0.0383 - 259ms/epoch - 1ms/step
# Epoch 29/190
# 214/214 - 0s - loss: 0.0383 - 281ms/epoch - 1ms/step
# Epoch 30/190
# 214/214 - 0s - loss: 0.0383 - 272ms/epoch - 1ms/step
# Epoch 31/190
# 214/214 - 0s - loss: 0.0383 - 303ms/epoch - 1ms/step
# Epoch 32/190
# 214/214 - 0s - loss: 0.0383 - 279ms/epoch - 1ms/step
# Epoch 33/190
# 214/214 - 0s - loss: 0.0383 - 277ms/epoch - 1ms/step
# Epoch 34/190
# 214/214 - 0s - loss: 0.0383 - 271ms/epoch - 1ms/step
# Epoch 35/190
# 214/214 - 0s - loss: 0.0383 - 237ms/epoch - 1ms/step
# Epoch 36/190
# 214/214 - 0s - loss: 0.0383 - 284ms/epoch - 1ms/step
# Epoch 37/190
# 214/214 - 0s - loss: 0.0383 - 265ms/epoch - 1ms/step
# Epoch 38/190
# 214/214 - 0s - loss: 0.0383 - 269ms/epoch - 1ms/step
# Epoch 39/190
# 214/214 - 0s - loss: 0.0383 - 260ms/epoch - 1ms/step
# Epoch 40/190
# 214/214 - 0s - loss: 0.0383 - 263ms/epoch - 1ms/step
# Epoch 41/190
# 214/214 - 0s - loss: 0.0383 - 252ms/epoch - 1ms/step
# Epoch 42/190
# 214/214 - 0s - loss: 0.0383 - 260ms/epoch - 1ms/step
# Epoch 43/190
# 214/214 - 0s - loss: 0.0383 - 243ms/epoch - 1ms/step
# Epoch 44/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 45/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 46/190
# 214/214 - 0s - loss: 0.0383 - 262ms/epoch - 1ms/step
# Epoch 47/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 48/190
# 214/214 - 0s - loss: 0.0383 - 272ms/epoch - 1ms/step
# Epoch 49/190
# 214/214 - 0s - loss: 0.0383 - 280ms/epoch - 1ms/step
# Epoch 50/190
# 214/214 - 0s - loss: 0.0383 - 283ms/epoch - 1ms/step
# Epoch 51/190
# 214/214 - 0s - loss: 0.0383 - 286ms/epoch - 1ms/step
# Epoch 52/190
# 214/214 - 0s - loss: 0.0383 - 282ms/epoch - 1ms/step
# Epoch 53/190
# 214/214 - 0s - loss: 0.0383 - 266ms/epoch - 1ms/step
# Epoch 54/190
# 214/214 - 0s - loss: 0.0383 - 253ms/epoch - 1ms/step
# Epoch 55/190
# 214/214 - 0s - loss: 0.0383 - 248ms/epoch - 1ms/step
# Epoch 56/190
# 214/214 - 0s - loss: 0.0383 - 260ms/epoch - 1ms/step
# Epoch 57/190
# 214/214 - 0s - loss: 0.0383 - 294ms/epoch - 1ms/step
# Epoch 58/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 59/190
# 214/214 - 0s - loss: 0.0383 - 249ms/epoch - 1ms/step
# Epoch 60/190
# 214/214 - 0s - loss: 0.0383 - 275ms/epoch - 1ms/step
# Epoch 61/190
# 214/214 - 0s - loss: 0.0383 - 259ms/epoch - 1ms/step
# Epoch 62/190
# 214/214 - 0s - loss: 0.0383 - 253ms/epoch - 1ms/step
# Epoch 63/190
# 214/214 - 0s - loss: 0.0383 - 273ms/epoch - 1ms/step
# Epoch 64/190
# 214/214 - 0s - loss: 0.0383 - 294ms/epoch - 1ms/step
# Epoch 65/190
# 214/214 - 0s - loss: 0.0383 - 270ms/epoch - 1ms/step
# Epoch 66/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 67/190
# 214/214 - 0s - loss: 0.0383 - 257ms/epoch - 1ms/step
# Epoch 68/190
# 214/214 - 0s - loss: 0.0383 - 262ms/epoch - 1ms/step
# Epoch 69/190
# 214/214 - 0s - loss: 0.0383 - 248ms/epoch - 1ms/step
# Epoch 70/190
# 214/214 - 0s - loss: 0.0383 - 271ms/epoch - 1ms/step
# Epoch 71/190
# 214/214 - 0s - loss: 0.0383 - 269ms/epoch - 1ms/step
# Epoch 72/190
# 214/214 - 0s - loss: 0.0383 - 261ms/epoch - 1ms/step
# Epoch 73/190
# 214/214 - 0s - loss: 0.0383 - 263ms/epoch - 1ms/step
# Epoch 74/190
# 214/214 - 0s - loss: 0.0383 - 252ms/epoch - 1ms/step
# Epoch 75/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 76/190
# 214/214 - 0s - loss: 0.0383 - 248ms/epoch - 1ms/step
# Epoch 77/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 78/190
# 214/214 - 0s - loss: 0.0383 - 272ms/epoch - 1ms/step
# Epoch 79/190
# 214/214 - 0s - loss: 0.0383 - 269ms/epoch - 1ms/step
# Epoch 80/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 81/190
# 214/214 - 0s - loss: 0.0383 - 245ms/epoch - 1ms/step
# Epoch 82/190
# 214/214 - 0s - loss: 0.0383 - 247ms/epoch - 1ms/step
# Epoch 83/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 84/190
# 214/214 - 0s - loss: 0.0383 - 261ms/epoch - 1ms/step
# Epoch 85/190
# 214/214 - 0s - loss: 0.0383 - 263ms/epoch - 1ms/step
# Epoch 86/190
# 214/214 - 0s - loss: 0.0383 - 286ms/epoch - 1ms/step
# Epoch 87/190
# 214/214 - 0s - loss: 0.0383 - 291ms/epoch - 1ms/step
# Epoch 88/190
# 214/214 - 0s - loss: 0.0383 - 274ms/epoch - 1ms/step
# Epoch 89/190
# 214/214 - 0s - loss: 0.0383 - 269ms/epoch - 1ms/step
# Epoch 90/190
# 214/214 - 0s - loss: 0.0383 - 273ms/epoch - 1ms/step
# Epoch 91/190
# 214/214 - 0s - loss: 0.0383 - 265ms/epoch - 1ms/step
# Epoch 92/190
# 214/214 - 0s - loss: 0.0383 - 247ms/epoch - 1ms/step
# Epoch 93/190
# 214/214 - 0s - loss: 0.0383 - 275ms/epoch - 1ms/step
# Epoch 94/190
# 214/214 - 0s - loss: 0.0383 - 268ms/epoch - 1ms/step
# Epoch 95/190
# 214/214 - 0s - loss: 0.0383 - 290ms/epoch - 1ms/step
# Epoch 96/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 97/190
# 214/214 - 0s - loss: 0.0383 - 270ms/epoch - 1ms/step
# Epoch 98/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 99/190
# 214/214 - 0s - loss: 0.0383 - 266ms/epoch - 1ms/step
# Epoch 100/190
# 214/214 - 0s - loss: 0.0383 - 247ms/epoch - 1ms/step
# Epoch 101/190
# 214/214 - 0s - loss: 0.0383 - 268ms/epoch - 1ms/step
# Epoch 102/190
# 214/214 - 0s - loss: 0.0383 - 274ms/epoch - 1ms/step
# Epoch 103/190
# 214/214 - 0s - loss: 0.0383 - 268ms/epoch - 1ms/step
# Epoch 104/190
# 214/214 - 0s - loss: 0.0383 - 247ms/epoch - 1ms/step
# Epoch 105/190
# 214/214 - 0s - loss: 0.0383 - 274ms/epoch - 1ms/step
# Epoch 106/190
# 214/214 - 0s - loss: 0.0383 - 256ms/epoch - 1ms/step
# Epoch 107/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 108/190
# 214/214 - 0s - loss: 0.0383 - 279ms/epoch - 1ms/step
# Epoch 109/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 110/190
# 214/214 - 0s - loss: 0.0383 - 292ms/epoch - 1ms/step
# Epoch 111/190
# 214/214 - 0s - loss: 0.0383 - 241ms/epoch - 1ms/step
# Epoch 112/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 113/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 114/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 115/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 116/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 117/190
# 214/214 - 0s - loss: 0.0383 - 259ms/epoch - 1ms/step
# Epoch 118/190
# 214/214 - 0s - loss: 0.0383 - 259ms/epoch - 1ms/step
# Epoch 119/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 120/190
# 214/214 - 0s - loss: 0.0383 - 279ms/epoch - 1ms/step
# Epoch 121/190
# 214/214 - 0s - loss: 0.0383 - 260ms/epoch - 1ms/step
# Epoch 122/190
# 214/214 - 0s - loss: 0.0383 - 249ms/epoch - 1ms/step
# Epoch 123/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 124/190
# 214/214 - 0s - loss: 0.0383 - 262ms/epoch - 1ms/step
# Epoch 125/190
# 214/214 - 0s - loss: 0.0383 - 285ms/epoch - 1ms/step
# Epoch 126/190
# 214/214 - 0s - loss: 0.0383 - 244ms/epoch - 1ms/step
# Epoch 127/190
# 214/214 - 0s - loss: 0.0383 - 253ms/epoch - 1ms/step
# Epoch 128/190
# 214/214 - 0s - loss: 0.0383 - 264ms/epoch - 1ms/step
# Epoch 129/190
# 214/214 - 0s - loss: 0.0383 - 282ms/epoch - 1ms/step
# Epoch 130/190
# 214/214 - 0s - loss: 0.0383 - 246ms/epoch - 1ms/step
# Epoch 131/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 132/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 133/190
# 214/214 - 0s - loss: 0.0383 - 268ms/epoch - 1ms/step
# Epoch 134/190
# 214/214 - 0s - loss: 0.0383 - 246ms/epoch - 1ms/step
# Epoch 135/190
# 214/214 - 0s - loss: 0.0383 - 265ms/epoch - 1ms/step
# Epoch 136/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 137/190
# 214/214 - 0s - loss: 0.0383 - 279ms/epoch - 1ms/step
# Epoch 138/190
# 214/214 - 0s - loss: 0.0383 - 264ms/epoch - 1ms/step
# Epoch 139/190
# 214/214 - 0s - loss: 0.0383 - 257ms/epoch - 1ms/step
# Epoch 140/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 141/190
# 214/214 - 0s - loss: 0.0383 - 264ms/epoch - 1ms/step
# Epoch 142/190
# 214/214 - 0s - loss: 0.0383 - 279ms/epoch - 1ms/step
# Epoch 143/190
# 214/214 - 0s - loss: 0.0383 - 266ms/epoch - 1ms/step
# Epoch 144/190
# 214/214 - 0s - loss: 0.0383 - 270ms/epoch - 1ms/step
# Epoch 145/190
# 214/214 - 0s - loss: 0.0383 - 262ms/epoch - 1ms/step
# Epoch 146/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 147/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 148/190
# 214/214 - 0s - loss: 0.0383 - 256ms/epoch - 1ms/step
# Epoch 149/190
# 214/214 - 0s - loss: 0.0383 - 253ms/epoch - 1ms/step
# Epoch 150/190
# 214/214 - 0s - loss: 0.0383 - 275ms/epoch - 1ms/step
# Epoch 151/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 152/190
# 214/214 - 0s - loss: 0.0383 - 265ms/epoch - 1ms/step
# Epoch 153/190
# 214/214 - 0s - loss: 0.0383 - 282ms/epoch - 1ms/step
# Epoch 154/190
# 214/214 - 0s - loss: 0.0383 - 271ms/epoch - 1ms/step
# Epoch 155/190
# 214/214 - 0s - loss: 0.0383 - 282ms/epoch - 1ms/step
# Epoch 156/190
# 214/214 - 0s - loss: 0.0383 - 283ms/epoch - 1ms/step
# Epoch 157/190
# 214/214 - 0s - loss: 0.0383 - 248ms/epoch - 1ms/step
# Epoch 158/190
# 214/214 - 0s - loss: 0.0383 - 254ms/epoch - 1ms/step
# Epoch 159/190
# 214/214 - 0s - loss: 0.0383 - 278ms/epoch - 1ms/step
# Epoch 160/190
# 214/214 - 0s - loss: 0.0383 - 276ms/epoch - 1ms/step
# Epoch 161/190
# 214/214 - 0s - loss: 0.0383 - 291ms/epoch - 1ms/step
# Epoch 162/190
# 214/214 - 0s - loss: 0.0383 - 282ms/epoch - 1ms/step
# Epoch 163/190
# 214/214 - 0s - loss: 0.0383 - 252ms/epoch - 1ms/step
# Epoch 164/190
# 214/214 - 0s - loss: 0.0383 - 255ms/epoch - 1ms/step
# Epoch 165/190
# 214/214 - 0s - loss: 0.0383 - 274ms/epoch - 1ms/step
# Epoch 166/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 167/190
# 214/214 - 0s - loss: 0.0383 - 260ms/epoch - 1ms/step
# Epoch 168/190
# 214/214 - 0s - loss: 0.0383 - 263ms/epoch - 1ms/step
# Epoch 169/190
# 214/214 - 0s - loss: 0.0383 - 258ms/epoch - 1ms/step
# Epoch 170/190
# 214/214 - 0s - loss: 0.0383 - 250ms/epoch - 1ms/step
# Epoch 171/190
# 214/214 - 0s - loss: 0.0383 - 268ms/epoch - 1ms/step
# Epoch 172/190
# 214/214 - 0s - loss: 0.0383 - 283ms/epoch - 1ms/step
# Epoch 173/190
# 214/214 - 0s - loss: 0.0383 - 281ms/epoch - 1ms/step
# Epoch 174/190
# 214/214 - 0s - loss: 0.0383 - 271ms/epoch - 1ms/step
# Epoch 175/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 176/190
# 214/214 - 0s - loss: 0.0383 - 260ms/epoch - 1ms/step
# Epoch 177/190
# 214/214 - 0s - loss: 0.0383 - 259ms/epoch - 1ms/step
# Epoch 178/190
# 214/214 - 0s - loss: 0.0383 - 295ms/epoch - 1ms/step
# Epoch 179/190
# 214/214 - 0s - loss: 0.0383 - 279ms/epoch - 1ms/step
# Epoch 180/190
# 214/214 - 0s - loss: 0.0383 - 245ms/epoch - 1ms/step
# Epoch 181/190
# 214/214 - 0s - loss: 0.0383 - 245ms/epoch - 1ms/step
# Epoch 182/190
# 214/214 - 0s - loss: 0.0383 - 288ms/epoch - 1ms/step
# Epoch 183/190
# 214/214 - 0s - loss: 0.0383 - 274ms/epoch - 1ms/step
# Epoch 184/190
# 214/214 - 0s - loss: 0.0383 - 264ms/epoch - 1ms/step
# Epoch 185/190
# 214/214 - 0s - loss: 0.0383 - 290ms/epoch - 1ms/step
# Epoch 186/190
# 214/214 - 0s - loss: 0.0383 - 266ms/epoch - 1ms/step
# Epoch 187/190
# 214/214 - 0s - loss: 0.0383 - 267ms/epoch - 1ms/step
# Epoch 188/190
# 214/214 - 0s - loss: 0.0383 - 248ms/epoch - 1ms/step
# Epoch 189/190
# 214/214 - 0s - loss: 0.0383 - 246ms/epoch - 1ms/step
# Epoch 190/190
# 214/214 - 0s - loss: 0.0383 - 265ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step
# Epoch 1/200
# 214/214 - 1s - loss: 0.0023 - 679ms/epoch - 3ms/step
# Epoch 2/200
# 214/214 - 0s - loss: 0.0012 - 297ms/epoch - 1ms/step
# Epoch 3/200
# 214/214 - 0s - loss: 8.6235e-04 - 277ms/epoch - 1ms/step
# Epoch 4/200
# 214/214 - 0s - loss: 7.4253e-04 - 291ms/epoch - 1ms/step
# Epoch 5/200
# 214/214 - 0s - loss: 6.6773e-04 - 282ms/epoch - 1ms/step
# Epoch 6/200
# 214/214 - 0s - loss: 5.5244e-04 - 279ms/epoch - 1ms/step
# Epoch 7/200
# 214/214 - 0s - loss: 5.3817e-04 - 263ms/epoch - 1ms/step
# Epoch 8/200
# 214/214 - 0s - loss: 5.0617e-04 - 263ms/epoch - 1ms/step
# Epoch 9/200
# 214/214 - 0s - loss: 4.4022e-04 - 265ms/epoch - 1ms/step
# Epoch 10/200
# 214/214 - 0s - loss: 4.2873e-04 - 248ms/epoch - 1ms/step
# Epoch 11/200
# 214/214 - 0s - loss: 3.9438e-04 - 288ms/epoch - 1ms/step
# Epoch 12/200
# 214/214 - 0s - loss: 3.7135e-04 - 252ms/epoch - 1ms/step
# Epoch 13/200
# 214/214 - 0s - loss: 3.5543e-04 - 273ms/epoch - 1ms/step
# Epoch 14/200
# 214/214 - 0s - loss: 3.3179e-04 - 271ms/epoch - 1ms/step
# Epoch 15/200
# 214/214 - 0s - loss: 3.1625e-04 - 266ms/epoch - 1ms/step
# Epoch 16/200
# 214/214 - 0s - loss: 3.0625e-04 - 498ms/epoch - 2ms/step
# Epoch 17/200
# 214/214 - 0s - loss: 2.9327e-04 - 268ms/epoch - 1ms/step
# Epoch 18/200
# 214/214 - 0s - loss: 2.8264e-04 - 259ms/epoch - 1ms/step
# Epoch 19/200
# 214/214 - 0s - loss: 2.9048e-04 - 289ms/epoch - 1ms/step
# Epoch 20/200
# 214/214 - 0s - loss: 2.6082e-04 - 262ms/epoch - 1ms/step
# Epoch 21/200
# 214/214 - 0s - loss: 2.7395e-04 - 256ms/epoch - 1ms/step
# Epoch 22/200
# 214/214 - 0s - loss: 2.7910e-04 - 248ms/epoch - 1ms/step
# Epoch 23/200
# 214/214 - 0s - loss: 2.7476e-04 - 261ms/epoch - 1ms/step
# Epoch 24/200
# 214/214 - 0s - loss: 2.5804e-04 - 260ms/epoch - 1ms/step
# Epoch 25/200
# 214/214 - 0s - loss: 2.5601e-04 - 272ms/epoch - 1ms/step
# Epoch 26/200
# 214/214 - 0s - loss: 2.5409e-04 - 252ms/epoch - 1ms/step
# Epoch 27/200
# 214/214 - 0s - loss: 2.6126e-04 - 265ms/epoch - 1ms/step
# Epoch 28/200
# 214/214 - 0s - loss: 2.5355e-04 - 273ms/epoch - 1ms/step
# Epoch 29/200
# 214/214 - 0s - loss: 2.4974e-04 - 289ms/epoch - 1ms/step
# Epoch 30/200
# 214/214 - 0s - loss: 2.5725e-04 - 264ms/epoch - 1ms/step
# Epoch 31/200
# 214/214 - 0s - loss: 2.4648e-04 - 275ms/epoch - 1ms/step
# Epoch 32/200
# 214/214 - 0s - loss: 2.4407e-04 - 280ms/epoch - 1ms/step
# Epoch 33/200
# 214/214 - 0s - loss: 2.4051e-04 - 259ms/epoch - 1ms/step
# Epoch 34/200
# 214/214 - 0s - loss: 2.3936e-04 - 275ms/epoch - 1ms/step
# Epoch 35/200
# 214/214 - 0s - loss: 2.3764e-04 - 264ms/epoch - 1ms/step
# Epoch 36/200
# 214/214 - 0s - loss: 2.2981e-04 - 267ms/epoch - 1ms/step
# Epoch 37/200
# 214/214 - 0s - loss: 2.3556e-04 - 260ms/epoch - 1ms/step
# Epoch 38/200
# 214/214 - 0s - loss: 2.3674e-04 - 252ms/epoch - 1ms/step
# Epoch 39/200
# 214/214 - 0s - loss: 2.2146e-04 - 256ms/epoch - 1ms/step
# Epoch 40/200
# 214/214 - 0s - loss: 2.3871e-04 - 254ms/epoch - 1ms/step
# Epoch 41/200
# 214/214 - 0s - loss: 2.2305e-04 - 246ms/epoch - 1ms/step
# Epoch 42/200
# 214/214 - 0s - loss: 2.1928e-04 - 267ms/epoch - 1ms/step
# Epoch 43/200
# 214/214 - 0s - loss: 2.3271e-04 - 257ms/epoch - 1ms/step
# Epoch 44/200
# 214/214 - 0s - loss: 2.1566e-04 - 268ms/epoch - 1ms/step
# Epoch 45/200
# 214/214 - 0s - loss: 2.2959e-04 - 239ms/epoch - 1ms/step
# Epoch 46/200
# 214/214 - 0s - loss: 2.1735e-04 - 279ms/epoch - 1ms/step
# Epoch 47/200
# 214/214 - 0s - loss: 2.1617e-04 - 256ms/epoch - 1ms/step
# Epoch 48/200
# 214/214 - 0s - loss: 2.1619e-04 - 265ms/epoch - 1ms/step
# Epoch 49/200
# 214/214 - 0s - loss: 2.1072e-04 - 266ms/epoch - 1ms/step
# Epoch 50/200
# 214/214 - 0s - loss: 2.1147e-04 - 259ms/epoch - 1ms/step
# Epoch 51/200
# 214/214 - 0s - loss: 2.1716e-04 - 253ms/epoch - 1ms/step
# Epoch 52/200
# 214/214 - 0s - loss: 2.0481e-04 - 257ms/epoch - 1ms/step
# Epoch 53/200
# 214/214 - 0s - loss: 2.0276e-04 - 274ms/epoch - 1ms/step
# Epoch 54/200
# 214/214 - 0s - loss: 2.1599e-04 - 251ms/epoch - 1ms/step
# Epoch 55/200
# 214/214 - 0s - loss: 2.0494e-04 - 260ms/epoch - 1ms/step
# Epoch 56/200
# 214/214 - 0s - loss: 2.0560e-04 - 245ms/epoch - 1ms/step
# Epoch 57/200
# 214/214 - 0s - loss: 2.0593e-04 - 254ms/epoch - 1ms/step
# Epoch 58/200
# 214/214 - 0s - loss: 1.9680e-04 - 262ms/epoch - 1ms/step
# Epoch 59/200
# 214/214 - 0s - loss: 1.9409e-04 - 281ms/epoch - 1ms/step
# Epoch 60/200
# 214/214 - 0s - loss: 2.0022e-04 - 262ms/epoch - 1ms/step
# Epoch 61/200
# 214/214 - 0s - loss: 1.9796e-04 - 266ms/epoch - 1ms/step
# Epoch 62/200
# 214/214 - 0s - loss: 2.0874e-04 - 282ms/epoch - 1ms/step
# Epoch 63/200
# 214/214 - 0s - loss: 1.8890e-04 - 259ms/epoch - 1ms/step
# Epoch 64/200
# 214/214 - 0s - loss: 1.9102e-04 - 250ms/epoch - 1ms/step
# Epoch 65/200
# 214/214 - 0s - loss: 1.9262e-04 - 266ms/epoch - 1ms/step
# Epoch 66/200
# 214/214 - 0s - loss: 1.8966e-04 - 250ms/epoch - 1ms/step
# Epoch 67/200
# 214/214 - 0s - loss: 1.9751e-04 - 257ms/epoch - 1ms/step
# Epoch 68/200
# 214/214 - 0s - loss: 1.8346e-04 - 290ms/epoch - 1ms/step
# Epoch 69/200
# 214/214 - 0s - loss: 1.9779e-04 - 255ms/epoch - 1ms/step
# Epoch 70/200
# 214/214 - 0s - loss: 1.8729e-04 - 240ms/epoch - 1ms/step
# Epoch 71/200
# 214/214 - 0s - loss: 1.9646e-04 - 262ms/epoch - 1ms/step
# Epoch 72/200
# 214/214 - 0s - loss: 1.8948e-04 - 265ms/epoch - 1ms/step
# Epoch 73/200
# 214/214 - 0s - loss: 1.7979e-04 - 252ms/epoch - 1ms/step
# Epoch 74/200
# 214/214 - 0s - loss: 1.8746e-04 - 258ms/epoch - 1ms/step
# Epoch 75/200
# 214/214 - 0s - loss: 1.8018e-04 - 255ms/epoch - 1ms/step
# Epoch 76/200
# 214/214 - 0s - loss: 1.8463e-04 - 253ms/epoch - 1ms/step
# Epoch 77/200
# 214/214 - 0s - loss: 1.7132e-04 - 265ms/epoch - 1ms/step
# Epoch 78/200
# 214/214 - 0s - loss: 1.8394e-04 - 246ms/epoch - 1ms/step
# Epoch 79/200
# 214/214 - 0s - loss: 1.8131e-04 - 262ms/epoch - 1ms/step
# Epoch 80/200
# 214/214 - 0s - loss: 1.7583e-04 - 276ms/epoch - 1ms/step
# Epoch 81/200
# 214/214 - 0s - loss: 1.7393e-04 - 253ms/epoch - 1ms/step
# Epoch 82/200
# 214/214 - 0s - loss: 1.7887e-04 - 276ms/epoch - 1ms/step
# Epoch 83/200
# 214/214 - 0s - loss: 1.7121e-04 - 287ms/epoch - 1ms/step
# Epoch 84/200
# 214/214 - 0s - loss: 1.8673e-04 - 257ms/epoch - 1ms/step
# Epoch 85/200
# 214/214 - 0s - loss: 1.8272e-04 - 245ms/epoch - 1ms/step
# Epoch 86/200
# 214/214 - 0s - loss: 1.7410e-04 - 255ms/epoch - 1ms/step
# Epoch 87/200
# 214/214 - 0s - loss: 1.7364e-04 - 253ms/epoch - 1ms/step
# Epoch 88/200
# 214/214 - 0s - loss: 1.8429e-04 - 278ms/epoch - 1ms/step
# Epoch 89/200
# 214/214 - 0s - loss: 1.7294e-04 - 257ms/epoch - 1ms/step
# Epoch 90/200
# 214/214 - 0s - loss: 1.7264e-04 - 266ms/epoch - 1ms/step
# Epoch 91/200
# 214/214 - 0s - loss: 1.6927e-04 - 278ms/epoch - 1ms/step
# Epoch 92/200
# 214/214 - 0s - loss: 1.7126e-04 - 294ms/epoch - 1ms/step
# Epoch 93/200
# 214/214 - 0s - loss: 1.7752e-04 - 311ms/epoch - 1ms/step
# Epoch 94/200
# 214/214 - 0s - loss: 1.7295e-04 - 267ms/epoch - 1ms/step
# Epoch 95/200
# 214/214 - 0s - loss: 1.7686e-04 - 266ms/epoch - 1ms/step
# Epoch 96/200
# 214/214 - 0s - loss: 1.7833e-04 - 253ms/epoch - 1ms/step
# Epoch 97/200
# 214/214 - 0s - loss: 1.6985e-04 - 252ms/epoch - 1ms/step
# Epoch 98/200
# 214/214 - 0s - loss: 1.6992e-04 - 265ms/epoch - 1ms/step
# Epoch 99/200
# 214/214 - 0s - loss: 1.7433e-04 - 258ms/epoch - 1ms/step
# Epoch 100/200
# 214/214 - 0s - loss: 1.7108e-04 - 258ms/epoch - 1ms/step
# Epoch 101/200
# 214/214 - 0s - loss: 1.6836e-04 - 262ms/epoch - 1ms/step
# Epoch 102/200
# 214/214 - 0s - loss: 1.7161e-04 - 285ms/epoch - 1ms/step
# Epoch 103/200
# 214/214 - 0s - loss: 1.7653e-04 - 258ms/epoch - 1ms/step
# Epoch 104/200
# 214/214 - 0s - loss: 1.7097e-04 - 262ms/epoch - 1ms/step
# Epoch 105/200
# 214/214 - 0s - loss: 1.6366e-04 - 252ms/epoch - 1ms/step
# Epoch 106/200
# 214/214 - 0s - loss: 1.6691e-04 - 285ms/epoch - 1ms/step
# Epoch 107/200
# 214/214 - 0s - loss: 1.7540e-04 - 278ms/epoch - 1ms/step
# Epoch 108/200
# 214/214 - 0s - loss: 1.6971e-04 - 251ms/epoch - 1ms/step
# Epoch 109/200
# 214/214 - 0s - loss: 1.6643e-04 - 278ms/epoch - 1ms/step
# Epoch 110/200
# 214/214 - 0s - loss: 1.7157e-04 - 264ms/epoch - 1ms/step
# Epoch 111/200
# 214/214 - 0s - loss: 1.6982e-04 - 273ms/epoch - 1ms/step
# Epoch 112/200
# 214/214 - 0s - loss: 1.6013e-04 - 307ms/epoch - 1ms/step
# Epoch 113/200
# 214/214 - 0s - loss: 1.6684e-04 - 263ms/epoch - 1ms/step
# Epoch 114/200
# 214/214 - 0s - loss: 1.6777e-04 - 267ms/epoch - 1ms/step
# Epoch 115/200
# 214/214 - 0s - loss: 1.7206e-04 - 252ms/epoch - 1ms/step
# Epoch 116/200
# 214/214 - 0s - loss: 1.5551e-04 - 271ms/epoch - 1ms/step
# Epoch 117/200
# 214/214 - 0s - loss: 1.6796e-04 - 283ms/epoch - 1ms/step
# Epoch 118/200
# 214/214 - 0s - loss: 1.6227e-04 - 271ms/epoch - 1ms/step
# Epoch 119/200
# 214/214 - 0s - loss: 1.7035e-04 - 261ms/epoch - 1ms/step
# Epoch 120/200
# 214/214 - 0s - loss: 1.7110e-04 - 272ms/epoch - 1ms/step
# Epoch 121/200
# 214/214 - 0s - loss: 1.6273e-04 - 258ms/epoch - 1ms/step
# Epoch 122/200
# 214/214 - 0s - loss: 1.6764e-04 - 256ms/epoch - 1ms/step
# Epoch 123/200
# 214/214 - 0s - loss: 1.6931e-04 - 291ms/epoch - 1ms/step
# Epoch 124/200
# 214/214 - 0s - loss: 1.6795e-04 - 274ms/epoch - 1ms/step
# Epoch 125/200
# 214/214 - 0s - loss: 1.6769e-04 - 248ms/epoch - 1ms/step
# Epoch 126/200
# 214/214 - 0s - loss: 1.6337e-04 - 243ms/epoch - 1ms/step
# Epoch 127/200
# 214/214 - 0s - loss: 1.6833e-04 - 262ms/epoch - 1ms/step
# Epoch 128/200
# 214/214 - 0s - loss: 1.6088e-04 - 266ms/epoch - 1ms/step
# Epoch 129/200
# 214/214 - 0s - loss: 1.6884e-04 - 284ms/epoch - 1ms/step
# Epoch 130/200
# 214/214 - 0s - loss: 1.5383e-04 - 269ms/epoch - 1ms/step
# Epoch 131/200
# 214/214 - 0s - loss: 1.6441e-04 - 266ms/epoch - 1ms/step
# Epoch 132/200
# 214/214 - 0s - loss: 1.6751e-04 - 257ms/epoch - 1ms/step
# Epoch 133/200
# 214/214 - 0s - loss: 1.6489e-04 - 258ms/epoch - 1ms/step
# Epoch 134/200
# 214/214 - 0s - loss: 1.6084e-04 - 269ms/epoch - 1ms/step
# Epoch 135/200
# 214/214 - 0s - loss: 1.6651e-04 - 268ms/epoch - 1ms/step
# Epoch 136/200
# 214/214 - 0s - loss: 1.6802e-04 - 256ms/epoch - 1ms/step
# Epoch 137/200
# 214/214 - 0s - loss: 1.6374e-04 - 251ms/epoch - 1ms/step
# Epoch 138/200
# 214/214 - 0s - loss: 1.5730e-04 - 262ms/epoch - 1ms/step
# Epoch 139/200
# 214/214 - 0s - loss: 1.6043e-04 - 277ms/epoch - 1ms/step
# Epoch 140/200
# 214/214 - 0s - loss: 1.5646e-04 - 261ms/epoch - 1ms/step
# Epoch 141/200
# 214/214 - 0s - loss: 1.5777e-04 - 256ms/epoch - 1ms/step
# Epoch 142/200
# 214/214 - 0s - loss: 1.5799e-04 - 274ms/epoch - 1ms/step
# Epoch 143/200
# 214/214 - 0s - loss: 1.7216e-04 - 284ms/epoch - 1ms/step
# Epoch 144/200
# 214/214 - 0s - loss: 1.5858e-04 - 283ms/epoch - 1ms/step
# Epoch 145/200
# 214/214 - 0s - loss: 1.6458e-04 - 250ms/epoch - 1ms/step
# Epoch 146/200
# 214/214 - 0s - loss: 1.6331e-04 - 284ms/epoch - 1ms/step
# Epoch 147/200
# 214/214 - 0s - loss: 1.5286e-04 - 254ms/epoch - 1ms/step
# Epoch 148/200
# 214/214 - 0s - loss: 1.5930e-04 - 279ms/epoch - 1ms/step
# Epoch 149/200
# 214/214 - 0s - loss: 1.5498e-04 - 247ms/epoch - 1ms/step
# Epoch 150/200
# 214/214 - 0s - loss: 1.6910e-04 - 266ms/epoch - 1ms/step
# Epoch 151/200
# 214/214 - 0s - loss: 1.6499e-04 - 267ms/epoch - 1ms/step
# Epoch 152/200
# 214/214 - 0s - loss: 1.5890e-04 - 253ms/epoch - 1ms/step
# Epoch 153/200
# 214/214 - 0s - loss: 1.5919e-04 - 274ms/epoch - 1ms/step
# Epoch 154/200
# 214/214 - 0s - loss: 1.5741e-04 - 304ms/epoch - 1ms/step
# Epoch 155/200
# 214/214 - 0s - loss: 1.6427e-04 - 288ms/epoch - 1ms/step
# Epoch 156/200
# 214/214 - 0s - loss: 1.5889e-04 - 269ms/epoch - 1ms/step
# Epoch 157/200
# 214/214 - 0s - loss: 1.6188e-04 - 284ms/epoch - 1ms/step
# Epoch 158/200
# 214/214 - 0s - loss: 1.5805e-04 - 253ms/epoch - 1ms/step
# Epoch 159/200
# 214/214 - 0s - loss: 1.6214e-04 - 263ms/epoch - 1ms/step
# Epoch 160/200
# 214/214 - 0s - loss: 1.6062e-04 - 254ms/epoch - 1ms/step
# Epoch 161/200
# 214/214 - 0s - loss: 1.7061e-04 - 278ms/epoch - 1ms/step
# Epoch 162/200
# 214/214 - 0s - loss: 1.5423e-04 - 240ms/epoch - 1ms/step
# Epoch 163/200
# 214/214 - 0s - loss: 1.5873e-04 - 267ms/epoch - 1ms/step
# Epoch 164/200
# 214/214 - 0s - loss: 1.5888e-04 - 255ms/epoch - 1ms/step
# Epoch 165/200
# 214/214 - 0s - loss: 1.6456e-04 - 273ms/epoch - 1ms/step
# Epoch 166/200
# 214/214 - 0s - loss: 1.6576e-04 - 244ms/epoch - 1ms/step
# Epoch 167/200
# 214/214 - 0s - loss: 1.5976e-04 - 261ms/epoch - 1ms/step
# Epoch 168/200
# 214/214 - 0s - loss: 1.5899e-04 - 273ms/epoch - 1ms/step
# Epoch 169/200
# 214/214 - 0s - loss: 1.6577e-04 - 273ms/epoch - 1ms/step
# Epoch 170/200
# 214/214 - 0s - loss: 1.5084e-04 - 255ms/epoch - 1ms/step
# Epoch 171/200
# 214/214 - 0s - loss: 1.5532e-04 - 243ms/epoch - 1ms/step
# Epoch 172/200
# 214/214 - 0s - loss: 1.6018e-04 - 268ms/epoch - 1ms/step
# Epoch 173/200
# 214/214 - 0s - loss: 1.5396e-04 - 258ms/epoch - 1ms/step
# Epoch 174/200
# 214/214 - 0s - loss: 1.6545e-04 - 263ms/epoch - 1ms/step
# Epoch 175/200
# 214/214 - 0s - loss: 1.7164e-04 - 250ms/epoch - 1ms/step
# Epoch 176/200
# 214/214 - 0s - loss: 1.6203e-04 - 273ms/epoch - 1ms/step
# Epoch 177/200
# 214/214 - 0s - loss: 1.5059e-04 - 253ms/epoch - 1ms/step
# Epoch 178/200
# 214/214 - 0s - loss: 1.5848e-04 - 282ms/epoch - 1ms/step
# Epoch 179/200
# 214/214 - 0s - loss: 1.5456e-04 - 312ms/epoch - 1ms/step
# Epoch 180/200
# 214/214 - 0s - loss: 1.6053e-04 - 260ms/epoch - 1ms/step
# Epoch 181/200
# 214/214 - 0s - loss: 1.6281e-04 - 268ms/epoch - 1ms/step
# Epoch 182/200
# 214/214 - 0s - loss: 1.5937e-04 - 250ms/epoch - 1ms/step
# Epoch 183/200
# 214/214 - 0s - loss: 1.5128e-04 - 254ms/epoch - 1ms/step
# Epoch 184/200
# 214/214 - 0s - loss: 1.5579e-04 - 255ms/epoch - 1ms/step
# Epoch 185/200
# 214/214 - 0s - loss: 1.5943e-04 - 253ms/epoch - 1ms/step
# Epoch 186/200
# 214/214 - 0s - loss: 1.6163e-04 - 263ms/epoch - 1ms/step
# Epoch 187/200
# 214/214 - 0s - loss: 1.6624e-04 - 276ms/epoch - 1ms/step
# Epoch 188/200
# 214/214 - 0s - loss: 1.5861e-04 - 273ms/epoch - 1ms/step
# Epoch 189/200
# 214/214 - 0s - loss: 1.5634e-04 - 247ms/epoch - 1ms/step
# Epoch 190/200
# 214/214 - 0s - loss: 1.5991e-04 - 280ms/epoch - 1ms/step
# Epoch 191/200
# 214/214 - 0s - loss: 1.5484e-04 - 298ms/epoch - 1ms/step
# Epoch 192/200
# 214/214 - 0s - loss: 1.6673e-04 - 243ms/epoch - 1ms/step
# Epoch 193/200
# 214/214 - 0s - loss: 1.6684e-04 - 247ms/epoch - 1ms/step
# Epoch 194/200
# 214/214 - 0s - loss: 1.6043e-04 - 295ms/epoch - 1ms/step
# Epoch 195/200
# 214/214 - 0s - loss: 1.6015e-04 - 265ms/epoch - 1ms/step
# Epoch 196/200
# 214/214 - 0s - loss: 1.5030e-04 - 267ms/epoch - 1ms/step
# Epoch 197/200
# 214/214 - 0s - loss: 1.6143e-04 - 253ms/epoch - 1ms/step
# Epoch 198/200
# 214/214 - 0s - loss: 1.5873e-04 - 253ms/epoch - 1ms/step
# Epoch 199/200
# 214/214 - 0s - loss: 1.6534e-04 - 263ms/epoch - 1ms/step
# Epoch 200/200
# 214/214 - 0s - loss: 1.5759e-04 - 249ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step
# Epoch 1/200
# 214/214 - 1s - loss: 0.0029 - 601ms/epoch - 3ms/step
# Epoch 2/200
# 214/214 - 0s - loss: 1.2612e-04 - 263ms/epoch - 1ms/step
# Epoch 3/200
# 214/214 - 0s - loss: 1.1653e-04 - 269ms/epoch - 1ms/step
# Epoch 4/200
# 214/214 - 0s - loss: 1.1866e-04 - 285ms/epoch - 1ms/step
# Epoch 5/200
# 214/214 - 0s - loss: 1.1952e-04 - 246ms/epoch - 1ms/step
# Epoch 6/200
# 214/214 - 0s - loss: 1.3119e-04 - 257ms/epoch - 1ms/step
# Epoch 7/200
# 214/214 - 0s - loss: 1.3297e-04 - 252ms/epoch - 1ms/step
# Epoch 8/200
# 214/214 - 0s - loss: 1.3652e-04 - 270ms/epoch - 1ms/step
# Epoch 9/200
# 214/214 - 0s - loss: 1.3976e-04 - 254ms/epoch - 1ms/step
# Epoch 10/200
# 214/214 - 0s - loss: 1.6714e-04 - 262ms/epoch - 1ms/step
# Epoch 11/200
# 214/214 - 0s - loss: 2.1036e-04 - 258ms/epoch - 1ms/step
# Epoch 12/200
# 214/214 - 0s - loss: 1.7210e-04 - 279ms/epoch - 1ms/step
# Epoch 13/200
# 214/214 - 0s - loss: 2.1630e-04 - 251ms/epoch - 1ms/step
# Epoch 14/200
# 214/214 - 0s - loss: 1.9520e-04 - 260ms/epoch - 1ms/step
# Epoch 15/200
# 214/214 - 0s - loss: 2.0938e-04 - 252ms/epoch - 1ms/step
# Epoch 16/200
# 214/214 - 0s - loss: 2.2593e-04 - 265ms/epoch - 1ms/step
# Epoch 17/200
# 214/214 - 0s - loss: 1.9016e-04 - 247ms/epoch - 1ms/step
# Epoch 18/200
# 214/214 - 0s - loss: 1.9244e-04 - 269ms/epoch - 1ms/step
# Epoch 19/200
# 214/214 - 0s - loss: 1.9679e-04 - 272ms/epoch - 1ms/step
# Epoch 20/200
# 214/214 - 0s - loss: 1.2829e-04 - 278ms/epoch - 1ms/step
# Epoch 21/200
# 214/214 - 0s - loss: 1.7510e-04 - 257ms/epoch - 1ms/step
# Epoch 22/200
# 214/214 - 0s - loss: 1.2053e-04 - 271ms/epoch - 1ms/step
# Epoch 23/200
# 214/214 - 0s - loss: 1.4038e-04 - 261ms/epoch - 1ms/step
# Epoch 24/200
# 214/214 - 0s - loss: 1.1609e-04 - 274ms/epoch - 1ms/step
# Epoch 25/200
# 214/214 - 0s - loss: 1.3778e-04 - 268ms/epoch - 1ms/step
# Epoch 26/200
# 214/214 - 0s - loss: 1.4598e-04 - 272ms/epoch - 1ms/step
# Epoch 27/200
# 214/214 - 0s - loss: 1.4493e-04 - 290ms/epoch - 1ms/step
# Epoch 28/200
# 214/214 - 0s - loss: 1.1124e-04 - 264ms/epoch - 1ms/step
# Epoch 29/200
# 214/214 - 0s - loss: 1.4589e-04 - 261ms/epoch - 1ms/step
# Epoch 30/200
# 214/214 - 0s - loss: 1.4946e-04 - 254ms/epoch - 1ms/step
# Epoch 31/200
# 214/214 - 0s - loss: 1.5465e-04 - 261ms/epoch - 1ms/step
# Epoch 32/200
# 214/214 - 0s - loss: 1.4619e-04 - 250ms/epoch - 1ms/step
# Epoch 33/200
# 214/214 - 0s - loss: 1.3192e-04 - 263ms/epoch - 1ms/step
# Epoch 34/200
# 214/214 - 0s - loss: 1.0996e-04 - 282ms/epoch - 1ms/step
# Epoch 35/200
# 214/214 - 0s - loss: 1.2326e-04 - 259ms/epoch - 1ms/step
# Epoch 36/200
# 214/214 - 0s - loss: 1.2911e-04 - 255ms/epoch - 1ms/step
# Epoch 37/200
# 214/214 - 0s - loss: 1.0958e-04 - 290ms/epoch - 1ms/step
# Epoch 38/200
# 214/214 - 0s - loss: 1.1811e-04 - 272ms/epoch - 1ms/step
# Epoch 39/200
# 214/214 - 0s - loss: 1.5206e-04 - 254ms/epoch - 1ms/step
# Epoch 40/200
# 214/214 - 0s - loss: 1.4725e-04 - 264ms/epoch - 1ms/step
# Epoch 41/200
# 214/214 - 0s - loss: 1.4184e-04 - 269ms/epoch - 1ms/step
# Epoch 42/200
# 214/214 - 0s - loss: 1.2135e-04 - 261ms/epoch - 1ms/step
# Epoch 43/200
# 214/214 - 0s - loss: 1.3858e-04 - 251ms/epoch - 1ms/step
# Epoch 44/200
# 214/214 - 0s - loss: 1.2254e-04 - 255ms/epoch - 1ms/step
# Epoch 45/200
# 214/214 - 0s - loss: 1.1872e-04 - 256ms/epoch - 1ms/step
# Epoch 46/200
# 214/214 - 0s - loss: 1.6096e-04 - 258ms/epoch - 1ms/step
# Epoch 47/200
# 214/214 - 0s - loss: 1.1482e-04 - 257ms/epoch - 1ms/step
# Epoch 48/200
# 214/214 - 0s - loss: 1.3357e-04 - 258ms/epoch - 1ms/step
# Epoch 49/200
# 214/214 - 0s - loss: 9.9109e-05 - 264ms/epoch - 1ms/step
# Epoch 50/200
# 214/214 - 0s - loss: 1.0915e-04 - 262ms/epoch - 1ms/step
# Epoch 51/200
# 214/214 - 0s - loss: 1.2638e-04 - 251ms/epoch - 1ms/step
# Epoch 52/200
# 214/214 - 0s - loss: 1.2129e-04 - 267ms/epoch - 1ms/step
# Epoch 53/200
# 214/214 - 0s - loss: 1.1063e-04 - 274ms/epoch - 1ms/step
# Epoch 54/200
# 214/214 - 0s - loss: 1.3164e-04 - 258ms/epoch - 1ms/step
# Epoch 55/200
# 214/214 - 0s - loss: 1.3003e-04 - 246ms/epoch - 1ms/step
# Epoch 56/200
# 214/214 - 0s - loss: 1.4506e-04 - 268ms/epoch - 1ms/step
# Epoch 57/200
# 214/214 - 0s - loss: 1.5819e-04 - 274ms/epoch - 1ms/step
# Epoch 58/200
# 214/214 - 0s - loss: 1.5770e-04 - 268ms/epoch - 1ms/step
# Epoch 59/200
# 214/214 - 0s - loss: 1.4401e-04 - 270ms/epoch - 1ms/step
# Epoch 60/200
# 214/214 - 0s - loss: 1.2628e-04 - 251ms/epoch - 1ms/step
# Epoch 61/200
# 214/214 - 0s - loss: 1.3505e-04 - 259ms/epoch - 1ms/step
# Epoch 62/200
# 214/214 - 0s - loss: 1.1857e-04 - 263ms/epoch - 1ms/step
# Epoch 63/200
# 214/214 - 0s - loss: 1.0682e-04 - 277ms/epoch - 1ms/step
# Epoch 64/200
# 214/214 - 0s - loss: 1.2520e-04 - 247ms/epoch - 1ms/step
# Epoch 65/200
# 214/214 - 0s - loss: 1.6780e-04 - 259ms/epoch - 1ms/step
# Epoch 66/200
# 214/214 - 0s - loss: 1.0075e-04 - 244ms/epoch - 1ms/step
# Epoch 67/200
# 214/214 - 0s - loss: 1.6728e-04 - 271ms/epoch - 1ms/step
# Epoch 68/200
# 214/214 - 0s - loss: 1.6520e-04 - 272ms/epoch - 1ms/step
# Epoch 69/200
# 214/214 - 0s - loss: 1.5117e-04 - 285ms/epoch - 1ms/step
# Epoch 70/200
# 214/214 - 0s - loss: 1.1341e-04 - 270ms/epoch - 1ms/step
# Epoch 71/200
# 214/214 - 0s - loss: 1.5287e-04 - 260ms/epoch - 1ms/step
# Epoch 72/200
# 214/214 - 0s - loss: 1.3047e-04 - 266ms/epoch - 1ms/step
# Epoch 73/200
# 214/214 - 0s - loss: 1.0231e-04 - 259ms/epoch - 1ms/step
# Epoch 74/200
# 214/214 - 0s - loss: 1.3853e-04 - 269ms/epoch - 1ms/step
# Epoch 75/200
# 214/214 - 0s - loss: 1.3338e-04 - 252ms/epoch - 1ms/step
# Epoch 76/200
# 214/214 - 0s - loss: 1.4555e-04 - 248ms/epoch - 1ms/step
# Epoch 77/200
# 214/214 - 0s - loss: 1.4689e-04 - 259ms/epoch - 1ms/step
# Epoch 78/200
# 214/214 - 0s - loss: 1.3344e-04 - 245ms/epoch - 1ms/step
# Epoch 79/200
# 214/214 - 0s - loss: 1.5261e-04 - 251ms/epoch - 1ms/step
# Epoch 80/200
# 214/214 - 0s - loss: 1.2935e-04 - 250ms/epoch - 1ms/step
# Epoch 81/200
# 214/214 - 0s - loss: 1.8560e-04 - 255ms/epoch - 1ms/step
# Epoch 82/200
# 214/214 - 0s - loss: 1.2037e-04 - 252ms/epoch - 1ms/step
# Epoch 83/200
# 214/214 - 0s - loss: 1.5776e-04 - 237ms/epoch - 1ms/step
# Epoch 84/200
# 214/214 - 0s - loss: 1.3154e-04 - 246ms/epoch - 1ms/step
# Epoch 85/200
# 214/214 - 0s - loss: 1.5114e-04 - 252ms/epoch - 1ms/step
# Epoch 86/200
# 214/214 - 0s - loss: 1.4242e-04 - 268ms/epoch - 1ms/step
# Epoch 87/200
# 214/214 - 0s - loss: 1.3882e-04 - 251ms/epoch - 1ms/step
# Epoch 88/200
# 214/214 - 0s - loss: 1.0891e-04 - 267ms/epoch - 1ms/step
# Epoch 89/200
# 214/214 - 0s - loss: 1.0134e-04 - 273ms/epoch - 1ms/step
# Epoch 90/200
# 214/214 - 0s - loss: 2.2476e-04 - 276ms/epoch - 1ms/step
# Epoch 91/200
# 214/214 - 0s - loss: 9.6893e-05 - 272ms/epoch - 1ms/step
# Epoch 92/200
# 214/214 - 0s - loss: 1.4638e-04 - 270ms/epoch - 1ms/step
# Epoch 93/200
# 214/214 - 0s - loss: 1.2841e-04 - 259ms/epoch - 1ms/step
# Epoch 94/200
# 214/214 - 0s - loss: 1.5206e-04 - 254ms/epoch - 1ms/step
# Epoch 95/200
# 214/214 - 0s - loss: 1.8596e-04 - 270ms/epoch - 1ms/step
# Epoch 96/200
# 214/214 - 0s - loss: 1.3102e-04 - 282ms/epoch - 1ms/step
# Epoch 97/200
# 214/214 - 0s - loss: 1.3441e-04 - 260ms/epoch - 1ms/step
# Epoch 98/200
# 214/214 - 0s - loss: 1.2688e-04 - 250ms/epoch - 1ms/step
# Epoch 99/200
# 214/214 - 0s - loss: 1.2960e-04 - 249ms/epoch - 1ms/step
# Epoch 100/200
# 214/214 - 0s - loss: 1.3262e-04 - 267ms/epoch - 1ms/step
# Epoch 101/200
# 214/214 - 0s - loss: 1.6080e-04 - 270ms/epoch - 1ms/step
# Epoch 102/200
# 214/214 - 0s - loss: 1.2967e-04 - 269ms/epoch - 1ms/step
# Epoch 103/200
# 214/214 - 0s - loss: 1.3087e-04 - 246ms/epoch - 1ms/step
# Epoch 104/200
# 214/214 - 0s - loss: 1.3295e-04 - 259ms/epoch - 1ms/step
# Epoch 105/200
# 214/214 - 0s - loss: 1.3023e-04 - 254ms/epoch - 1ms/step
# Epoch 106/200
# 214/214 - 0s - loss: 1.7117e-04 - 249ms/epoch - 1ms/step
# Epoch 107/200
# 214/214 - 0s - loss: 1.1624e-04 - 259ms/epoch - 1ms/step
# Epoch 108/200
# 214/214 - 0s - loss: 1.9585e-04 - 265ms/epoch - 1ms/step
# Epoch 109/200
# 214/214 - 0s - loss: 1.1880e-04 - 290ms/epoch - 1ms/step
# Epoch 110/200
# 214/214 - 0s - loss: 1.1684e-04 - 284ms/epoch - 1ms/step
# Epoch 111/200
# 214/214 - 0s - loss: 1.4320e-04 - 268ms/epoch - 1ms/step
# Epoch 112/200
# 214/214 - 0s - loss: 1.1076e-04 - 268ms/epoch - 1ms/step
# Epoch 113/200
# 214/214 - 0s - loss: 1.4732e-04 - 279ms/epoch - 1ms/step
# Epoch 114/200
# 214/214 - 0s - loss: 1.2191e-04 - 277ms/epoch - 1ms/step
# Epoch 115/200
# ...
# Epoch 179/200
# 214/214 - 0s - loss: 8.9040e-05 - 272ms/epoch - 1ms/step
# Epoch 180/200
# 214/214 - 0s - loss: 8.4813e-05 - 263ms/epoch - 1ms/step
# Epoch 181/200
# 214/214 - 0s - loss: 7.7335e-05 - 259ms/epoch - 1ms/step
# Epoch 182/200
# 214/214 - 0s - loss: 8.4146e-05 - 248ms/epoch - 1ms/step
# Epoch 183/200
# 214/214 - 0s - loss: 9.4046e-05 - 255ms/epoch - 1ms/step
# Epoch 184/200
# 214/214 - 0s - loss: 9.5835e-05 - 243ms/epoch - 1ms/step
# Epoch 185/200
# 214/214 - 0s - loss: 7.4340e-05 - 262ms/epoch - 1ms/step
# Epoch 186/200
# 214/214 - 0s - loss: 8.5572e-05 - 258ms/epoch - 1ms/step
# Epoch 187/200
# 214/214 - 0s - loss: 8.7350e-05 - 250ms/epoch - 1ms/step
# Epoch 188/200
# 214/214 - 0s - loss: 8.9229e-05 - 253ms/epoch - 1ms/step
# Epoch 189/200
# 214/214 - 0s - loss: 8.5035e-05 - 270ms/epoch - 1ms/step
# Epoch 190/200
# 214/214 - 0s - loss: 8.3997e-05 - 275ms/epoch - 1ms/step
# Epoch 191/200
# 214/214 - 0s - loss: 7.6743e-05 - 255ms/epoch - 1ms/step
# Epoch 192/200
# 214/214 - 0s - loss: 7.3293e-05 - 277ms/epoch - 1ms/step
# Epoch 193/200
# 214/214 - 0s - loss: 7.7638e-05 - 263ms/epoch - 1ms/step
# Epoch 194/200
# 214/214 - 0s - loss: 8.8602e-05 - 292ms/epoch - 1ms/step
# Epoch 195/200
# 214/214 - 0s - loss: 7.8248e-05 - 267ms/epoch - 1ms/step
# Epoch 196/200
# 214/214 - 0s - loss: 8.1996e-05 - 263ms/epoch - 1ms/step
# Epoch 197/200
# 214/214 - 0s - loss: 7.9955e-05 - 262ms/epoch - 1ms/step
# Epoch 198/200
# 214/214 - 0s - loss: 1.0120e-04 - 270ms/epoch - 1ms/step
# Epoch 199/200
# 214/214 - 0s - loss: 7.3271e-05 - 246ms/epoch - 1ms/step
# Epoch 200/200
# 214/214 - 0s - loss: 9.1616e-05 - 261ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step
# Epoch 1/200
# 214/214 - 1s - loss: 0.0391 - 596ms/epoch - 3ms/step
# Epoch 2/200
# 214/214 - 0s - loss: 0.0299 - 270ms/epoch - 1ms/step
# Epoch 3/200
# 214/214 - 0s - loss: 0.0241 - 280ms/epoch - 1ms/step
# Epoch 4/200
# 214/214 - 0s - loss: 0.0186 - 282ms/epoch - 1ms/step
# Epoch 5/200
# 214/214 - 0s - loss: 0.0132 - 283ms/epoch - 1ms/step
# Epoch 6/200
# 214/214 - 0s - loss: 0.0084 - 277ms/epoch - 1ms/step
# Epoch 7/200
# 214/214 - 0s - loss: 0.0046 - 269ms/epoch - 1ms/step
# Epoch 8/200
# 214/214 - 0s - loss: 0.0019 - 266ms/epoch - 1ms/step
# Epoch 9/200
# 214/214 - 0s - loss: 5.3062e-04 - 280ms/epoch - 1ms/step
# Epoch 10/200
# 214/214 - 0s - loss: 1.4579e-04 - 253ms/epoch - 1ms/step
# Epoch 11/200
# 214/214 - 0s - loss: 1.1497e-04 - 268ms/epoch - 1ms/step
# Epoch 12/200
# 214/214 - 0s - loss: 1.1558e-04 - 269ms/epoch - 1ms/step
# Epoch 13/200
# 214/214 - 0s - loss: 1.1570e-04 - 253ms/epoch - 1ms/step
# Epoch 14/200
# 214/214 - 0s - loss: 1.1512e-04 - 248ms/epoch - 1ms/step
# Epoch 15/200
# 214/214 - 0s - loss: 1.1499e-04 - 261ms/epoch - 1ms/step
# Epoch 16/200
# 214/214 - 0s - loss: 1.1428e-04 - 290ms/epoch - 1ms/step
# Epoch 17/200
# 214/214 - 0s - loss: 1.1294e-04 - 260ms/epoch - 1ms/step
# Epoch 18/200
# 214/214 - 0s - loss: 1.1390e-04 - 264ms/epoch - 1ms/step
# Epoch 19/200
# 214/214 - 0s - loss: 1.1471e-04 - 273ms/epoch - 1ms/step
# Epoch 20/200
# 214/214 - 0s - loss: 1.1434e-04 - 280ms/epoch - 1ms/step
# Epoch 21/200
# 214/214 - 0s - loss: 1.1558e-04 - 261ms/epoch - 1ms/step
# Epoch 22/200
# 214/214 - 0s - loss: 1.1449e-04 - 246ms/epoch - 1ms/step
# Epoch 23/200
# 214/214 - 0s - loss: 1.1338e-04 - 284ms/epoch - 1ms/step
# Epoch 24/200
# 214/214 - 0s - loss: 1.1339e-04 - 273ms/epoch - 1ms/step
# Epoch 25/200
# 214/214 - 0s - loss: 1.1379e-04 - 266ms/epoch - 1ms/step
# Epoch 26/200
# 214/214 - 0s - loss: 1.1458e-04 - 272ms/epoch - 1ms/step
# Epoch 27/200
# 214/214 - 0s - loss: 1.1356e-04 - 267ms/epoch - 1ms/step
# Epoch 28/200
# 214/214 - 0s - loss: 1.1358e-04 - 253ms/epoch - 1ms/step
# Epoch 29/200
# 214/214 - 0s - loss: 1.1386e-04 - 248ms/epoch - 1ms/step
# Epoch 30/200
# 214/214 - 0s - loss: 1.1478e-04 - 283ms/epoch - 1ms/step
# Epoch 31/200
# 214/214 - 0s - loss: 1.1325e-04 - 279ms/epoch - 1ms/step
# Epoch 32/200
# 214/214 - 0s - loss: 1.1322e-04 - 249ms/epoch - 1ms/step
# Epoch 33/200
# 214/214 - 0s - loss: 1.1440e-04 - 260ms/epoch - 1ms/step
# Epoch 34/200
# 214/214 - 0s - loss: 1.1242e-04 - 261ms/epoch - 1ms/step
# Epoch 35/200
# 214/214 - 0s - loss: 1.1394e-04 - 294ms/epoch - 1ms/step
# Epoch 36/200
# 214/214 - 0s - loss: 1.1309e-04 - 258ms/epoch - 1ms/step
# Epoch 37/200
# 214/214 - 0s - loss: 1.1289e-04 - 261ms/epoch - 1ms/step
# Epoch 38/200
# 214/214 - 0s - loss: 1.1266e-04 - 255ms/epoch - 1ms/step
# Epoch 39/200
# 214/214 - 0s - loss: 1.1248e-04 - 272ms/epoch - 1ms/step
# Epoch 40/200
# 214/214 - 0s - loss: 1.1313e-04 - 275ms/epoch - 1ms/step
# Epoch 41/200
# 214/214 - 0s - loss: 1.1413e-04 - 279ms/epoch - 1ms/step
# Epoch 42/200
# 214/214 - 0s - loss: 1.1283e-04 - 250ms/epoch - 1ms/step
# Epoch 43/200
# 214/214 - 0s - loss: 1.1313e-04 - 299ms/epoch - 1ms/step
# Epoch 44/200
# 214/214 - 0s - loss: 1.1159e-04 - 267ms/epoch - 1ms/step
# Epoch 45/200
# 214/214 - 0s - loss: 1.1135e-04 - 266ms/epoch - 1ms/step
# Epoch 46/200
# 214/214 - 0s - loss: 1.1179e-04 - 261ms/epoch - 1ms/step
# Epoch 47/200
# 214/214 - 0s - loss: 1.1262e-04 - 272ms/epoch - 1ms/step
# Epoch 48/200
# 214/214 - 0s - loss: 1.1211e-04 - 255ms/epoch - 1ms/step
# Epoch 49/200
# 214/214 - 0s - loss: 1.1201e-04 - 254ms/epoch - 1ms/step
# Epoch 50/200
# 214/214 - 0s - loss: 1.1238e-04 - 255ms/epoch - 1ms/step
# Epoch 51/200
# 214/214 - 0s - loss: 1.1271e-04 - 245ms/epoch - 1ms/step
# Epoch 52/200
# 214/214 - 0s - loss: 1.1176e-04 - 269ms/epoch - 1ms/step
# Epoch 53/200
# 214/214 - 0s - loss: 1.1166e-04 - 274ms/epoch - 1ms/step
# Epoch 54/200
# 214/214 - 0s - loss: 1.1070e-04 - 272ms/epoch - 1ms/step
# Epoch 55/200
# 214/214 - 0s - loss: 1.1154e-04 - 257ms/epoch - 1ms/step
# Epoch 56/200
# 214/214 - 0s - loss: 1.1159e-04 - 273ms/epoch - 1ms/step
# Epoch 57/200
# 214/214 - 0s - loss: 1.1163e-04 - 262ms/epoch - 1ms/step
# Epoch 58/200
# 214/214 - 0s - loss: 1.1071e-04 - 259ms/epoch - 1ms/step
# Epoch 59/200
# 214/214 - 0s - loss: 1.1189e-04 - 268ms/epoch - 1ms/step
# Epoch 60/200
# 214/214 - 0s - loss: 1.1108e-04 - 267ms/epoch - 1ms/step
# Epoch 61/200
# 214/214 - 0s - loss: 1.1237e-04 - 251ms/epoch - 1ms/step
# Epoch 62/200
# 214/214 - 0s - loss: 1.1304e-04 - 262ms/epoch - 1ms/step
# Epoch 63/200
# 214/214 - 0s - loss: 1.1128e-04 - 260ms/epoch - 1ms/step
# Epoch 64/200
# 214/214 - 0s - loss: 1.1056e-04 - 257ms/epoch - 1ms/step
# Epoch 65/200
# 214/214 - 0s - loss: 1.0929e-04 - 254ms/epoch - 1ms/step
# Epoch 66/200
# 214/214 - 0s - loss: 1.1104e-04 - 244ms/epoch - 1ms/step
# Epoch 67/200
# 214/214 - 0s - loss: 1.1189e-04 - 280ms/epoch - 1ms/step
# Epoch 68/200
# 214/214 - 0s - loss: 1.1144e-04 - 293ms/epoch - 1ms/step
# Epoch 69/200
# 214/214 - 0s - loss: 1.1001e-04 - 331ms/epoch - 2ms/step
# Epoch 70/200
# 214/214 - 0s - loss: 1.1002e-04 - 398ms/epoch - 2ms/step
# Epoch 71/200
# 214/214 - 0s - loss: 1.1046e-04 - 454ms/epoch - 2ms/step
# Epoch 72/200
# 214/214 - 0s - loss: 1.1029e-04 - 425ms/epoch - 2ms/step
# Epoch 73/200
# 214/214 - 0s - loss: 1.0987e-04 - 398ms/epoch - 2ms/step
# Epoch 74/200
# 214/214 - 0s - loss: 1.0975e-04 - 378ms/epoch - 2ms/step
# Epoch 75/200
# 214/214 - 0s - loss: 1.1038e-04 - 278ms/epoch - 1ms/step
# Epoch 76/200
# 214/214 - 0s - loss: 1.0989e-04 - 278ms/epoch - 1ms/step
# Epoch 77/200
# 214/214 - 0s - loss: 1.1009e-04 - 270ms/epoch - 1ms/step
# Epoch 78/200
# 214/214 - 0s - loss: 1.1049e-04 - 294ms/epoch - 1ms/step
# Epoch 79/200
# 214/214 - 0s - loss: 1.1001e-04 - 275ms/epoch - 1ms/step
# Epoch 80/200
# 214/214 - 0s - loss: 1.1036e-04 - 249ms/epoch - 1ms/step
# Epoch 81/200
# 214/214 - 0s - loss: 1.0810e-04 - 243ms/epoch - 1ms/step
# Epoch 82/200
# 214/214 - 0s - loss: 1.0973e-04 - 261ms/epoch - 1ms/step
# Epoch 83/200
# 214/214 - 0s - loss: 1.0922e-04 - 285ms/epoch - 1ms/step
# Epoch 84/200
# 214/214 - 0s - loss: 1.0829e-04 - 261ms/epoch - 1ms/step
# Epoch 85/200
# 214/214 - 0s - loss: 1.0948e-04 - 266ms/epoch - 1ms/step
# Epoch 86/200
# 214/214 - 0s - loss: 1.0888e-04 - 258ms/epoch - 1ms/step
# Epoch 87/200
# 214/214 - 0s - loss: 1.0857e-04 - 262ms/epoch - 1ms/step
# Epoch 88/200
# 214/214 - 0s - loss: 1.0903e-04 - 246ms/epoch - 1ms/step
# Epoch 89/200
# 214/214 - 0s - loss: 1.0764e-04 - 261ms/epoch - 1ms/step
# Epoch 90/200
# 214/214 - 0s - loss: 1.0831e-04 - 250ms/epoch - 1ms/step
# Epoch 91/200
# 214/214 - 0s - loss: 1.0882e-04 - 265ms/epoch - 1ms/step
# Epoch 92/200
# 214/214 - 0s - loss: 1.0838e-04 - 279ms/epoch - 1ms/step
# Epoch 93/200
# 214/214 - 0s - loss: 1.0859e-04 - 257ms/epoch - 1ms/step
# Epoch 94/200
# 214/214 - 0s - loss: 1.0848e-04 - 264ms/epoch - 1ms/step
# Epoch 95/200
# 214/214 - 0s - loss: 1.0848e-04 - 258ms/epoch - 1ms/step
# Epoch 96/200
# 214/214 - 0s - loss: 1.0870e-04 - 249ms/epoch - 1ms/step
# Epoch 97/200
# 214/214 - 0s - loss: 1.0818e-04 - 271ms/epoch - 1ms/step
# Epoch 98/200
# 214/214 - 0s - loss: 1.0851e-04 - 256ms/epoch - 1ms/step
# Epoch 99/200
# 214/214 - 0s - loss: 1.0828e-04 - 278ms/epoch - 1ms/step
# Epoch 100/200
# 214/214 - 0s - loss: 1.0774e-04 - 253ms/epoch - 1ms/step
# Epoch 101/200
# 214/214 - 0s - loss: 1.0678e-04 - 271ms/epoch - 1ms/step
# Epoch 102/200
# 214/214 - 0s - loss: 1.0842e-04 - 260ms/epoch - 1ms/step
# Epoch 103/200
# 214/214 - 0s - loss: 1.0849e-04 - 248ms/epoch - 1ms/step
# Epoch 104/200
# 214/214 - 0s - loss: 1.0852e-04 - 261ms/epoch - 1ms/step
# Epoch 105/200
# 214/214 - 0s - loss: 1.0695e-04 - 262ms/epoch - 1ms/step
# Epoch 106/200
# 214/214 - 0s - loss: 1.0685e-04 - 267ms/epoch - 1ms/step
# Epoch 107/200
# 214/214 - 0s - loss: 1.0693e-04 - 252ms/epoch - 1ms/step
# Epoch 108/200
# 214/214 - 0s - loss: 1.0765e-04 - 263ms/epoch - 1ms/step
# Epoch 109/200
# 214/214 - 0s - loss: 1.0740e-04 - 273ms/epoch - 1ms/step
# Epoch 110/200
# 214/214 - 0s - loss: 1.0708e-04 - 256ms/epoch - 1ms/step
# Epoch 111/200
# 214/214 - 0s - loss: 1.0680e-04 - 255ms/epoch - 1ms/step
# Epoch 112/200
# 214/214 - 0s - loss: 1.0781e-04 - 271ms/epoch - 1ms/step
# Epoch 113/200
# 214/214 - 0s - loss: 1.0670e-04 - 256ms/epoch - 1ms/step
# Epoch 114/200
# 214/214 - 0s - loss: 1.0646e-04 - 270ms/epoch - 1ms/step
# Epoch 115/200
# 214/214 - 0s - loss: 1.0782e-04 - 256ms/epoch - 1ms/step
# Epoch 116/200
# 214/214 - 0s - loss: 1.0754e-04 - 270ms/epoch - 1ms/step
# Epoch 117/200
# 214/214 - 0s - loss: 1.0755e-04 - 251ms/epoch - 1ms/step
# Epoch 118/200
# 214/214 - 0s - loss: 1.0700e-04 - 255ms/epoch - 1ms/step
# Epoch 119/200
# 214/214 - 0s - loss: 1.0561e-04 - 263ms/epoch - 1ms/step
# Epoch 120/200
# 214/214 - 0s - loss: 1.0570e-04 - 274ms/epoch - 1ms/step
# Epoch 121/200
# 214/214 - 0s - loss: 1.0599e-04 - 270ms/epoch - 1ms/step
# Epoch 122/200
# 214/214 - 0s - loss: 1.0691e-04 - 248ms/epoch - 1ms/step
# Epoch 123/200
# 214/214 - 0s - loss: 1.0743e-04 - 251ms/epoch - 1ms/step
# Epoch 124/200
# 214/214 - 0s - loss: 1.0533e-04 - 270ms/epoch - 1ms/step
# Epoch 125/200
# 214/214 - 0s - loss: 1.0710e-04 - 271ms/epoch - 1ms/step
# Epoch 126/200
# 214/214 - 0s - loss: 1.0698e-04 - 254ms/epoch - 1ms/step
# Epoch 127/200
# 214/214 - 0s - loss: 1.0648e-04 - 252ms/epoch - 1ms/step
# Epoch 128/200
# 214/214 - 0s - loss: 1.0541e-04 - 274ms/epoch - 1ms/step
# Epoch 129/200
# 214/214 - 0s - loss: 1.0611e-04 - 261ms/epoch - 1ms/step
# Epoch 130/200
# 214/214 - 0s - loss: 1.0605e-04 - 265ms/epoch - 1ms/step
# Epoch 131/200
# 214/214 - 0s - loss: 1.0536e-04 - 268ms/epoch - 1ms/step
# Epoch 132/200
# 214/214 - 0s - loss: 1.0444e-04 - 253ms/epoch - 1ms/step
# Epoch 133/200
# 214/214 - 0s - loss: 1.0665e-04 - 260ms/epoch - 1ms/step
# Epoch 134/200
# 214/214 - 0s - loss: 1.0462e-04 - 258ms/epoch - 1ms/step
# Epoch 135/200
# 214/214 - 0s - loss: 1.0478e-04 - 259ms/epoch - 1ms/step
# Epoch 136/200
# 214/214 - 0s - loss: 1.0560e-04 - 251ms/epoch - 1ms/step
# Epoch 137/200
# 214/214 - 0s - loss: 1.0578e-04 - 249ms/epoch - 1ms/step
# Epoch 138/200
# 214/214 - 0s - loss: 1.0489e-04 - 258ms/epoch - 1ms/step
# Epoch 139/200
# 214/214 - 0s - loss: 1.0570e-04 - 278ms/epoch - 1ms/step
# Epoch 140/200
# 214/214 - 0s - loss: 1.0475e-04 - 246ms/epoch - 1ms/step
# Epoch 141/200
# 214/214 - 0s - loss: 1.0503e-04 - 258ms/epoch - 1ms/step
# Epoch 142/200
# 214/214 - 0s - loss: 1.0522e-04 - 248ms/epoch - 1ms/step
# Epoch 143/200
# 214/214 - 0s - loss: 1.0468e-04 - 274ms/epoch - 1ms/step
# Epoch 144/200
# 214/214 - 0s - loss: 1.0484e-04 - 259ms/epoch - 1ms/step
# Epoch 145/200
# 214/214 - 0s - loss: 1.0429e-04 - 247ms/epoch - 1ms/step
# Epoch 146/200
# 214/214 - 0s - loss: 1.0461e-04 - 268ms/epoch - 1ms/step
# Epoch 147/200
# 214/214 - 0s - loss: 1.0449e-04 - 261ms/epoch - 1ms/step
# Epoch 148/200
# 214/214 - 0s - loss: 1.0547e-04 - 256ms/epoch - 1ms/step
# Epoch 149/200
# 214/214 - 0s - loss: 1.0398e-04 - 245ms/epoch - 1ms/step
# Epoch 150/200
# 214/214 - 0s - loss: 1.0484e-04 - 270ms/epoch - 1ms/step
# Epoch 151/200
# 214/214 - 0s - loss: 1.0519e-04 - 262ms/epoch - 1ms/step
# Epoch 152/200
# 214/214 - 0s - loss: 1.0420e-04 - 269ms/epoch - 1ms/step
# Epoch 153/200
# 214/214 - 0s - loss: 1.0436e-04 - 264ms/epoch - 1ms/step
# Epoch 154/200
# 214/214 - 0s - loss: 1.0279e-04 - 294ms/epoch - 1ms/step
# Epoch 155/200
# 214/214 - 0s - loss: 1.0241e-04 - 285ms/epoch - 1ms/step
# Epoch 156/200
# 214/214 - 0s - loss: 1.0461e-04 - 258ms/epoch - 1ms/step
# Epoch 157/200
# 214/214 - 0s - loss: 1.0323e-04 - 266ms/epoch - 1ms/step
# Epoch 158/200
# 214/214 - 0s - loss: 1.0329e-04 - 261ms/epoch - 1ms/step
# Epoch 159/200
# 214/214 - 0s - loss: 1.0301e-04 - 266ms/epoch - 1ms/step
# Epoch 160/200
# 214/214 - 0s - loss: 1.0384e-04 - 271ms/epoch - 1ms/step
# Epoch 161/200
# 214/214 - 0s - loss: 1.0383e-04 - 290ms/epoch - 1ms/step
# Epoch 162/200
# 214/214 - 0s - loss: 1.0425e-04 - 283ms/epoch - 1ms/step
# Epoch 163/200
# 214/214 - 0s - loss: 1.0335e-04 - 265ms/epoch - 1ms/step
# Epoch 164/200
# 214/214 - 0s - loss: 1.0395e-04 - 268ms/epoch - 1ms/step
# Epoch 165/200
# 214/214 - 0s - loss: 1.0278e-04 - 286ms/epoch - 1ms/step
# Epoch 166/200
# 214/214 - 0s - loss: 1.0419e-04 - 267ms/epoch - 1ms/step
# Epoch 167/200
# 214/214 - 0s - loss: 1.0340e-04 - 267ms/epoch - 1ms/step
# Epoch 168/200
# 214/214 - 0s - loss: 1.0395e-04 - 263ms/epoch - 1ms/step
# Epoch 169/200
# 214/214 - 0s - loss: 1.0209e-04 - 266ms/epoch - 1ms/step
# Epoch 170/200
# 214/214 - 0s - loss: 1.0373e-04 - 256ms/epoch - 1ms/step
# Epoch 171/200
# 214/214 - 0s - loss: 1.0396e-04 - 265ms/epoch - 1ms/step
# Epoch 172/200
# 214/214 - 0s - loss: 1.0362e-04 - 258ms/epoch - 1ms/step
# Epoch 173/200
# 214/214 - 0s - loss: 1.0258e-04 - 259ms/epoch - 1ms/step
# Epoch 174/200
# 214/214 - 0s - loss: 1.0226e-04 - 261ms/epoch - 1ms/step
# Epoch 175/200
# 214/214 - 0s - loss: 1.0254e-04 - 260ms/epoch - 1ms/step
# Epoch 176/200
# 214/214 - 0s - loss: 1.0362e-04 - 271ms/epoch - 1ms/step
# Epoch 177/200
# 214/214 - 0s - loss: 1.0312e-04 - 253ms/epoch - 1ms/step
# Epoch 178/200
# 214/214 - 0s - loss: 1.0241e-04 - 254ms/epoch - 1ms/step
# Epoch 179/200
# 214/214 - 0s - loss: 1.0301e-04 - 269ms/epoch - 1ms/step
# Epoch 180/200
# 214/214 - 0s - loss: 1.0231e-04 - 255ms/epoch - 1ms/step
# Epoch 181/200
# 214/214 - 0s - loss: 1.0397e-04 - 263ms/epoch - 1ms/step
# Epoch 182/200
# 214/214 - 0s - loss: 1.0224e-04 - 261ms/epoch - 1ms/step
# Epoch 183/200
# 214/214 - 0s - loss: 1.0290e-04 - 257ms/epoch - 1ms/step
# Epoch 184/200
# 214/214 - 0s - loss: 1.0092e-04 - 272ms/epoch - 1ms/step
# Epoch 185/200
# 214/214 - 0s - loss: 1.0245e-04 - 257ms/epoch - 1ms/step
# Epoch 186/200
# 214/214 - 0s - loss: 1.0142e-04 - 255ms/epoch - 1ms/step
# Epoch 187/200
# 214/214 - 0s - loss: 1.0285e-04 - 263ms/epoch - 1ms/step
# Epoch 188/200
# 214/214 - 0s - loss: 1.0153e-04 - 266ms/epoch - 1ms/step
# Epoch 189/200
# 214/214 - 0s - loss: 1.0241e-04 - 251ms/epoch - 1ms/step
# Epoch 190/200
# 214/214 - 0s - loss: 1.0153e-04 - 274ms/epoch - 1ms/step
# Epoch 191/200
# 214/214 - 0s - loss: 1.0341e-04 - 290ms/epoch - 1ms/step
# Epoch 192/200
# 214/214 - 0s - loss: 1.0165e-04 - 301ms/epoch - 1ms/step
# Epoch 193/200
# 214/214 - 0s - loss: 1.0097e-04 - 251ms/epoch - 1ms/step
# Epoch 194/200
# 214/214 - 0s - loss: 1.0130e-04 - 257ms/epoch - 1ms/step
# Epoch 195/200
# 214/214 - 0s - loss: 1.0196e-04 - 267ms/epoch - 1ms/step
# Epoch 196/200
# 214/214 - 0s - loss: 1.0205e-04 - 261ms/epoch - 1ms/step
# Epoch 197/200
# 214/214 - 0s - loss: 1.0101e-04 - 253ms/epoch - 1ms/step
# Epoch 198/200
# 214/214 - 0s - loss: 1.0243e-04 - 296ms/epoch - 1ms/step
# Epoch 199/200
# 214/214 - 0s - loss: 1.0070e-04 - 260ms/epoch - 1ms/step
# Epoch 200/200
# 214/214 - 0s - loss: 1.0105e-04 - 263ms/epoch - 1ms/step
# 18/18 [==============================] - 0s 2ms/step
# Best solution: [ 3.99       20.99        2.75385908  0.07490505  7.99        1.19233036
#   5.        ]
# Batch-size: 8, Epoch: 200, Opt: Adam, Learning-rate: 0.07490504994649072, NWI: zero, Activation: linear, n-hidden: 5
